# %% [markdown]
# # Neural Network - 3 tier approach
#
# embeddings -> category classification -> brand classification

# %% [markdown]
# ### Imports and configuration

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU")
else:
    device = torch.device("cpu")
    print("Using CPU")

# device = torch.device("cpu")  # Debugging purposes - easier to debug with CPU
# Out:
# Using GPU

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle

from sklearn.metrics import accuracy_score, precision_score, recall_score
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim

# %% [markdown]
# ### Load data from pkl file

# %%
class SimpleDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.float32)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# %%
folder_to_save_products_embeddings = "Tier_approach_logs_performacne"
train_embeddings = os.path.join(folder_to_save_products_embeddings, 'train_set_embeddings.pkl')
test_embeddings = os.path.join(folder_to_save_products_embeddings, 'test_set_embeddings.pkl')

# %%
BATCH_SIZE = 16

# CHANGE COLUMN NAMES AS NEEDED TO LOAD DATA:

# Load embeddings and labels from the pickle file
with open(train_embeddings, 'rb') as f:
    data = pickle.load(f)
    loaded_embeddings = data['embeddings']
    loaded_master_labels = data['master_labels']
    loaded_sub_labels = data['sub_labels']
    loaded_brand_labels = data['brand_labels']

train_data = loaded_embeddings

if isinstance(train_data, torch.Tensor):
    train_data = train_data.detach().cpu().numpy()  # Convert to NumPy array

if isinstance(loaded_master_labels, np.ndarray):
    loaded_master_labels = torch.from_numpy(loaded_master_labels)  # Convert to tensor

if isinstance(loaded_brand_labels, np.ndarray):
    loaded_brand_labels = torch.from_numpy(loaded_brand_labels)  # Convert to tensor

mapped_labels = False
if int(max(set(loaded_brand_labels)) + 1) != len(loaded_brand_labels.unique()):
    # Check if the mapping is off
    print(f'max label: {max(set(loaded_brand_labels))}, num of unique labels: {len(loaded_brand_labels.unique())} - remapping labels...')
    unique_labels = torch.unique(loaded_brand_labels)
    label_mapping = {old_label.item(): new_label for new_label, old_label in enumerate(unique_labels)}
    loaded_brand_labels = loaded_brand_labels.clone().apply_(lambda x: label_mapping[x])
    mapped_labels = True

train_num_master_cat = len(loaded_master_labels.unique())
train_num_brands = len(loaded_brand_labels.unique())
train_y_master_cat = loaded_master_labels.cpu()
train_y_brand = loaded_brand_labels.cpu()

# Print to verify the loaded data
print("Embeddings shape:", loaded_embeddings.shape)  # Should show the shape of the embeddings
print("number of Unique master categories:", train_num_master_cat)
print("number of Unique brands:", train_num_brands)
print('max category: ', max(loaded_master_labels))
print('min category: ', min(loaded_master_labels))
print('max brand class: ', max(loaded_brand_labels))
print('min brand class: ', min(loaded_brand_labels))
print("train_y_master_cat.shape:", train_y_master_cat.shape)
print("train_y_brand.shape:", train_y_brand.shape)

master_cat_dataset_train = SimpleDataset(train_data, train_y_master_cat)
master_cat_dataloader_train = DataLoader(master_cat_dataset_train, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Embeddings shape: torch.Size([87672, 1768])
# number of Unique master categories: 10
# number of Unique brands: 3892
# max category:  tensor(9)
# min category:  tensor(0)
# max brand class:  tensor(3891)
# min brand class:  tensor(0)
# train_y_master_cat.shape: torch.Size([87672])
# train_y_brand.shape: torch.Size([87672])
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\2680378259.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels, dtype=torch.float32)

# %%
# Load embeddings and labels from the pickle file

with open(test_embeddings, 'rb') as f:
    data = pickle.load(f)
    loaded_embeddings = data['embeddings']
    loaded_master_labels = data['master_labels']
    loaded_sub_labels = data['sub_labels']
    loaded_brand_labels = data['brand_labels']

test_data = loaded_embeddings

if isinstance(test_data, torch.Tensor):
    test_data = test_data.detach().cpu().numpy()  # Convert to NumPy array

if isinstance(loaded_brand_labels, np.ndarray):
    loaded_brand_labels = torch.from_numpy(loaded_brand_labels)  # Convert to tensor

if mapped_labels:
    # Apply the same label mapping to the test set if needed
    loaded_brand_labels = loaded_brand_labels.clone().apply_(lambda x: label_mapping.get(x, -1))
    
test_y_master_cat = loaded_master_labels.cpu()
test_y_brand = loaded_brand_labels.cpu()

# Print to verify the loaded data
print("Embeddings shape:", loaded_embeddings.shape)  # Should show the shape of the embeddings
print("number of Unique master categories:", len(loaded_master_labels.unique()))
print("number of Unique brands:", len(loaded_brand_labels.unique()))
print('max brand: ', max(loaded_brand_labels))
print('min brand: ', min(loaded_brand_labels))
print("test_y_master_cat.shape:", test_y_master_cat.shape)
print("test_y_brand.shape:", test_y_brand.shape)

master_cat_dataset_test = SimpleDataset(test_data, test_y_master_cat)
master_cat_dataloader_test = DataLoader(master_cat_dataset_test, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Embeddings shape: torch.Size([21919, 1768])
# number of Unique master categories: 10
# number of Unique brands: 3136
# max brand:  tensor(3891)
# min brand:  tensor(1)
# test_y_master_cat.shape: torch.Size([21919])
# test_y_brand.shape: torch.Size([21919])
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\2680378259.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels, dtype=torch.float32)

# %%
print("Train data (embeddings) shape:", train_data.shape)
print("Test data (embeddigs) shape:", test_data.shape)
print('Train label (category) shape: ', train_y_master_cat.shape)
print('Test label (category) shape: ', test_y_master_cat.shape)
print('Train label (brand) shape: ', train_y_brand.shape)
print('Test label (brand) shape: ', test_y_brand.shape)
# Out:
# Train data (embeddings) shape: (87672, 1768)
# Test data (embeddigs) shape: (21919, 1768)
# Train label (category) shape:  torch.Size([87672])
# Test label (category) shape:  torch.Size([21919])
# Train label (brand) shape:  torch.Size([87672])
# Test label (brand) shape:  torch.Size([21919])

# %% [markdown]
# # Neural Network

# %%
weights_file_name = "model.pth"

class classifierNN(nn.Module):
    def __init__(self, input_size, output_size, layer1=64, layer2=32, dropout_rate=0.2, lr=0.001):
        super(classifierNN, self).__init__()
        self.fc1 = nn.Linear(input_size, layer1)  # First hidden layer
        self.dropout1 = nn.Dropout(dropout_rate)   # Dropout layer after first hidden layer
        self.fc2 = nn.Linear(layer1, layer2)        # Second hidden layer
        self.dropout2 = nn.Dropout(dropout_rate)   # Dropout layer after second hidden layer
        self.fc3 = nn.Linear(layer2, output_size)   # Output layer
        self.relu = nn.ReLU()                       # Activation function
        self.optimizer = optim.Adam(self.parameters(), lr=lr)  
        self.criterion = nn.CrossEntropyLoss()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout1(x)  # Apply dropout after the first layer
        x = self.relu(self.fc2(x))
        x = self.dropout2(x)  # Apply dropout after the second layer
        x = self.fc3(x)
        return x

    def train_model(self, train_dataloader, val_dataloader, optimizer=None, num_epochs=100, k=10, save_directory=None, log_file=None):
        if save_directory:
            os.makedirs(save_directory, exist_ok=True)  # Create directory if it doesn't exist

        if optimizer is None:
            optimizer = self.optimizer
        self.train()  # Set the model to training mode
        for epoch in range(num_epochs):
            for features, labels in train_dataloader:
                optimizer.zero_grad()  # Clear gradients
                features = features.to(device)
                labels = labels.to(device)

                # Forward pass
                logits = self(features)
                labels = labels.long()
                loss = self.criterion(logits, labels)  # Reshape if needed

                # Backward pass
                loss.backward()
                optimizer.step()  # Update weights            

            if epoch % k == 0 or epoch == num_epochs - 1:
                # Evaluate on validation set
                _, val_loss, val_accuracy, strict_val_accuracy = self.evaluate(val_dataloader)
                self.train()
                
                log_message = (f"Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}, "
                           f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}, "
                           f"99% Accuracy: {strict_val_accuracy:.4f}")
                print(log_message)

                # If a log file is specified, append to it
                if save_directory:
                    if log_file:
                        log_path = os.path.join(save_directory, log_file)

                        if log_path.endswith(".txt"):  # Ensure it's a text file
                            with open(log_path, "a") as f:  # Open in append mode
                                f.write(log_message + "\n")
                        else:
                            print("Warning: Provided file is not a .txt file, skipping logging.")
                    file_name = os.path.join(save_directory, weights_file_name)
                    # Save the model
                    torch.save(self, file_name)

        return val_loss
    
    def evaluate(self, dataloader, device=device):
        self.eval()  # Set the model to evaluation mode
        total_loss = 0
        correct_predictions = 0
        strict_correct_predictions = 0
        total_samples = 0
        all_logits = []

        with torch.no_grad():  # No need to track gradients
            for features, labels in dataloader:
                features = features.to(device)
                labels = labels.to(device)

                # Forward pass
                logits = self(features)  # Get the raw logits
                all_logits.append(logits.cpu())
                labels = labels.long()

                # Compute loss
                loss = self.criterion(logits, labels)
                total_loss += loss.item()

                # Calculate accuracy
                probabilities = torch.softmax(logits, dim=1)
                predictions = torch.argmax(probabilities, axis=1)
                correct_predictions += (predictions == labels).sum().item()
                
                strict_predictions = (probabilities.max(dim=1).values >= 0.99) & (predictions == labels)
                strict_correct_predictions += strict_predictions.sum().item()

                total_samples += labels.size(0)

        all_logits = torch.cat(all_logits, dim=0)
        avg_loss = total_loss / len(dataloader)
        accuracy = correct_predictions / total_samples
        strict_accuracy = strict_correct_predictions / total_samples
        return all_logits, avg_loss, accuracy, strict_accuracy

# %% [markdown]
# ### Hyperparameter Tuning

# %%
def random_search(train_loader, val_loader, output_nodes, n_trials=10, epochs=10, k=5):
    best_model = None
    best_loss = float('inf')
    best_params = {}

    for i in range(n_trials):
        
        # CHANGE SEARCH PARAMETERS AS NEEDED:
    
        layer1 = np.random.randint(64, 1024)
        layer2 = np.random.randint(32, 1024)
        dropout_rate = np.random.uniform(0.05, 0.4)  
        learning_rate = 10**np.random.uniform(-6, -2)

        # layer1 = np.random.randint(8, 128)  # Number of neurons in first layer
        # layer2 = np.random.randint(8, 64)   # Number of neurons in second layer
        # dropout_rate = np.random.uniform(0.1, 0.5)  # Dropout rate
        # learning_rate = 10**np.random.uniform(-5, 0)  # Learning rate

        print(f'--- Params (iter {i+1}) ---')
        print(f'layer1: {layer1}, layer2: {layer2}, dropout: {dropout_rate}, learning_rate: {learning_rate}')
    
        # Initialize model, loss function, and optimizer
        embedding_size = train_data.shape[1]
        model = classifierNN(embedding_size, output_nodes, layer1=layer1, layer2=layer2, dropout_rate=dropout_rate)
        model.to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # Train model
        val_loss = model.train_model(train_dataloader=train_loader, val_dataloader=val_loader, optimizer=optimizer, num_epochs=epochs, k=k)

        # Update best model if current one is better
        if val_loss < best_loss:
            best_loss = val_loss
            best_model = model
            best_params = {'layer1': layer1, 'layer2': layer2, 'dropout_rate': dropout_rate, 'learning_rate': learning_rate}

    return best_model, best_params, best_loss

# %% [markdown]
# ### Evaluation

# %%
def get_threshold_metrics(logits, y_true, threshold=None):
    probs = torch.softmax(torch.tensor(logits), dim=1).numpy()
    y_pred = np.argmax(logits, axis=1)

    unique_images_test = len(y_true)  # Unique images in the test set
    unique_brands_test = len(np.unique(y_true))  # Unique brands in the test set

    if threshold:
        predicted_probabilities = probs[np.arange(len(probs)), y_pred]
        y_pred_threshold = np.where(predicted_probabilities >= threshold, y_pred, -1)

        accuracy = accuracy_score(y_true, y_pred_threshold)
        precision = precision_score(y_true, y_pred_threshold, average='macro', zero_division=0)
        recall = recall_score(y_true, y_pred_threshold, average='macro', zero_division=0)
        f1 = (2 * precision * recall) / (precision + recall) if (precision+recall>0) else 0.0
        
        valid_indices = predicted_probabilities >= threshold  # Get indices where predictions meet the threshold
        y_pred_adj =  y_pred_threshold[valid_indices]
        adj_accuracy = accuracy_score(y_true[valid_indices], y_pred_adj) if np.any(valid_indices) else 0.0
        unique_images_pred = len(y_pred_adj)
        unique_brands_pred = len(np.unique(y_pred_adj))

    else:
        accuracy = accuracy_score(y_true, y_pred)
        precision = precision_score(y_true, y_pred, average='macro')
        recall = recall_score(y_true, y_pred, average='macro')
        f1 = (2 * precision * recall) / (precision + recall)
        adj_accuracy = accuracy
        unique_images_pred = len(y_pred)
        unique_brands_pred = len(np.unique(y_pred))
    
    coverage_images = unique_images_pred / unique_images_test if unique_images_test > 0 else 0.0
    coverage_brands = unique_brands_pred / unique_brands_test if unique_brands_test > 0 else 0.0

    return accuracy, precision, recall, f1, adj_accuracy, coverage_images, coverage_brands


def evaluate_and_save_model_stats(logits, y_true, metrics_title, file_path=None, print_metrics=False):
    # Dictionary to store metrics for each threshold
    metrics_dict = {
        "Threshold": [],
        "Accuracy": [],
        "Precision": [],
        "Recall": [],
        "F1 Score": [],
        "Adjusted Accuracy": [],
        "Image Coverage": [],
        "Brand Coverage": []
    }

    # Evaluate metrics at default, 99%, and 95% thresholds
    for threshold, label in [(None, "Default"), (0.95, "95%"), (0.96, "96%"), (0.97, "97%"), (0.98, "98%"), (0.99, "99%")]:
        accuracy, precision, recall, f1, adj_accuracy, cov_img, cov_brand = get_threshold_metrics(logits, y_true, threshold)
        
        accuracy = round(accuracy, 3)
        precision = round(precision, 3)
        recall = round(recall, 3)
        f1 = round(f1, 3)
        adj_accuracy = round(adj_accuracy, 3)
        cov_img = round(cov_img, 3)
        cov_brand = round(cov_brand, 3)

        if print_metrics:
            # Print metrics to console
            print(f'\n--- {metrics_title} {label} Metrics ---')
            print(f'Accuracy: {accuracy}')
            print(f'Precision: {precision}')
            print(f'Recall: {recall}')
            print(f'F1 Score: {f1}')
            print(f'Adjusted Accuracy: {adj_accuracy}')
            print(f'Image Coverage: {cov_img}')
            print(f'Brand Coverage: {cov_brand}')
            
            # Store metrics in dictionary
            metrics_dict["Threshold"].append(label)
            metrics_dict["Accuracy"].append(accuracy)
            metrics_dict["Precision"].append(precision)
            metrics_dict["Recall"].append(recall)
            metrics_dict["F1 Score"].append(f1)
            metrics_dict["Adjusted Accuracy"].append(adj_accuracy)
            metrics_dict["Image Coverage"].append(cov_img)
            metrics_dict["Brand Coverage"].append(cov_brand)

    if file_path:
        metrics_df = pd.DataFrame(metrics_dict)

        definitions = {
        "Metric": [
            "Softmax Threshold",
            "Accuracy",
            "Adjusted Accuracy",
            "Coverage_images",
            "Coverage_brands"
        ],
        "Definition": [
            "No threshold: all images are used. 99% threshold: predictions meeting at least 99% softmax probability.",
            "Number of predictions meeting the threshold and are correct / test set size.",
            "Number of predictions meeting the threshold and are correct / Number of predictions meeting the threshold.",
            "Unique images meeting the threshold / unique images in test set.",
            "Unique brands meeting the threshold / unique brands in test set."
        ],
        "Example": [
            "100 images with 85 unique brands. Model classified 90 images correctly with no threshold. 80 images (55 unique brands) meet the 99% threshold, out of these 80 images 75 were classified correctly.",
            "No threshold accuracy: 0.90, 99% threshold accuracy: 0.75",
            "99% adjusted accuracy: 75/80 = 0.93",
            "99% Coverage_Images: 0.80",
            "99% Coverage_brands: 55/85 = 0.647"
        ]
        }
        definitions_df = pd.DataFrame(definitions)


        with pd.ExcelWriter(file_path) as writer:
            metrics_df.to_excel(writer, sheet_name="Metrics", index=False)
            definitions_df.to_excel(writer, sheet_name="Definitions", index=False)

        print(f"Metrics and definitions saved to {file_path}")

# %% [markdown]
# ### Neural Network Training

# %% [markdown]
# #### Category classifier

# %%
# Hyperparam tuning
best_model, best_params, best_loss = random_search(master_cat_dataloader_train, master_cat_dataloader_test, train_num_master_cat, n_trials=6, epochs=6, k=1)

print(f'Best Loss: {best_loss}')
print(f'Best Hyperparameters: {best_params}')


# Initialize model
logfilepath = "logs.txt"
current_time = datetime.now().strftime("%Y-%m-%d_%I-%M_%p")
dataset = 'BigBasket'
dataset_title = dataset + "_" if dataset else ''
save_directory = f"{dataset_title}Category_train_logs_{current_time}"

embedding_size = train_data.shape[1]
model_paths = []

# Can change params or use random search if performance isn't good:
model_cat = classifierNN(
    embedding_size, 
    train_num_master_cat, 
    layer1=best_params['layer1'], 
    layer2=best_params['layer2'], 
    dropout_rate=best_params['dropout_rate'], 
    lr=best_params['learning_rate']
    )

model_cat.to(device)
num_weights = sum(p.numel() for p in model_cat.parameters() if p.requires_grad)
print(f"Number of learnable weights: {num_weights}")


# Train the model

# For enabling training logs:
model_cat.train_model(master_cat_dataloader_train, master_cat_dataloader_test, num_epochs=50, k=1, save_directory=save_directory, log_file=logfilepath)
model_path = os.path.join(save_directory, weights_file_name)
model_paths.append(model_path)

# For disabling traning logs:
# model_cat.train_model(master_cat_dataloader_train, master_cat_dataloader_test, num_epochs=50, k=1)

logits_cat, loss_cat, accuracy_cat, strict_accuracy_cat = model_cat.evaluate(master_cat_dataloader_test)
logits_cat = logits_cat.cpu().numpy()


# Evaluate model
file_name = f"{dataset_title}category"
file_name = file_name + '_' if file_name else ''
cat_file_path = f'{save_directory}\\{file_name}metrics_output.xlsx'
evaluate_and_save_model_stats(logits_cat, test_y_master_cat, metrics_title=file_name, file_path=cat_file_path, print_metrics=True)
# Out:
# --- Params (iter 1) ---
# layer1: 382, layer2: 980, dropout: 0.23288839590977467, learning_rate: 0.0001142669379078059
# Epoch [1/6], Loss: 0.0002, Val Loss: 0.1104, Val Accuracy: 0.9678, 99% Accuracy: 0.8266
# Epoch [2/6], Loss: 0.4685, Val Loss: 0.0977, Val Accuracy: 0.9713, 99% Accuracy: 0.8517
# Epoch [3/6], Loss: 0.9461, Val Loss: 0.0890, Val Accuracy: 0.9749, 99% Accuracy: 0.8453
# Epoch [4/6], Loss: 0.0060, Val Loss: 0.0800, Val Accuracy: 0.9773, 99% Accuracy: 0.8724
# Epoch [5/6], Loss: 0.0000, Val Loss: 0.0775, Val Accuracy: 0.9792, 99% Accuracy: 0.8931
# Epoch [6/6], Loss: 0.0892, Val Loss: 0.0762, Val Accuracy: 0.9788, 99% Accuracy: 0.8739
# --- Params (iter 2) ---
# layer1: 987, layer2: 661, dropout: 0.32306500230368534, learning_rate: 7.644243621410023e-05
# Epoch [1/6], Loss: 0.0050, Val Loss: 0.1064, Val Accuracy: 0.9704, 99% Accuracy: 0.8226
# Epoch [2/6], Loss: 0.0032, Val Loss: 0.0895, Val Accuracy: 0.9734, 99% Accuracy: 0.8326
# Epoch [3/6], Loss: 0.0009, Val Loss: 0.0888, Val Accuracy: 0.9743, 99% Accuracy: 0.8650
# Epoch [4/6], Loss: 0.0915, Val Loss: 0.0813, Val Accuracy: 0.9758, 99% Accuracy: 0.8508
# Epoch [5/6], Loss: 0.0104, Val Loss: 0.0743, Val Accuracy: 0.9793, 99% Accuracy: 0.8862
# Epoch [6/6], Loss: 0.0001, Val Loss: 0.0724, Val Accuracy: 0.9789, 99% Accuracy: 0.8748
# --- Params (iter 3) ---
# layer1: 251, layer2: 893, dropout: 0.10360244995865289, learning_rate: 3.5448148153906346e-06
# Epoch [1/6], Loss: 0.1105, Val Loss: 0.1679, Val Accuracy: 0.9513, 99% Accuracy: 0.5249
# Epoch [2/6], Loss: 0.0209, Val Loss: 0.1284, Val Accuracy: 0.9615, 99% Accuracy: 0.6706
# Epoch [3/6], Loss: 0.0682, Val Loss: 0.1165, Val Accuracy: 0.9657, 99% Accuracy: 0.7273
# Epoch [4/6], Loss: 0.0173, Val Loss: 0.1088, Val Accuracy: 0.9679, 99% Accuracy: 0.7582
# Epoch [5/6], Loss: 0.0270, Val Loss: 0.1044, Val Accuracy: 0.9693, 99% Accuracy: 0.7704
# Epoch [6/6], Loss: 0.0676, Val Loss: 0.1019, Val Accuracy: 0.9701, 99% Accuracy: 0.7801
# --- Params (iter 4) ---
# layer1: 990, layer2: 202, dropout: 0.1834990189344538, learning_rate: 0.00010134924569475277
# Epoch [1/6], Loss: 0.0244, Val Loss: 0.1044, Val Accuracy: 0.9696, 99% Accuracy: 0.8298
# Epoch [2/6], Loss: 0.0016, Val Loss: 0.0876, Val Accuracy: 0.9744, 99% Accuracy: 0.8507
# Epoch [3/6], Loss: 0.0032, Val Loss: 0.0863, Val Accuracy: 0.9747, 99% Accuracy: 0.8710
# Epoch [4/6], Loss: 0.0016, Val Loss: 0.0807, Val Accuracy: 0.9754, 99% Accuracy: 0.8484
# Epoch [5/6], Loss: 0.0003, Val Loss: 0.0769, Val Accuracy: 0.9763, 99% Accuracy: 0.8660
# Epoch [6/6], Loss: 0.0000, Val Loss: 0.0732, Val Accuracy: 0.9792, 99% Accuracy: 0.8985
# --- Params (iter 5) ---
# layer1: 425, layer2: 57, dropout: 0.1686310446038287, learning_rate: 0.0009262744946287058
# Epoch [1/6], Loss: 0.0038, Val Loss: 0.1322, Val Accuracy: 0.9635, 99% Accuracy: 0.8093
# Epoch [2/6], Loss: 0.0043, Val Loss: 0.1539, Val Accuracy: 0.9630, 99% Accuracy: 0.8310
# Epoch [3/6], Loss: 0.0022, Val Loss: 0.1066, Val Accuracy: 0.9711, 99% Accuracy: 0.8808
# Epoch [4/6], Loss: 0.0007, Val Loss: 0.1270, Val Accuracy: 0.9694, 99% Accuracy: 0.8771
# Epoch [5/6], Loss: 0.1464, Val Loss: 0.1123, Val Accuracy: 0.9725, 99% Accuracy: 0.9088
# Epoch [6/6], Loss: 0.0003, Val Loss: 0.1035, Val Accuracy: 0.9731, 99% Accuracy: 0.8938
# --- Params (iter 6) ---
# layer1: 561, layer2: 913, dropout: 0.298925744493259, learning_rate: 0.0032669916654778667
# Epoch [1/6], Loss: 0.0000, Val Loss: 0.2509, Val Accuracy: 0.9495, 99% Accuracy: 0.8371
# Epoch [2/6], Loss: 0.3068, Val Loss: 0.2164, Val Accuracy: 0.9568, 99% Accuracy: 0.8470
# Epoch [3/6], Loss: 0.5848, Val Loss: 0.2239, Val Accuracy: 0.9382, 99% Accuracy: 0.8207
# Epoch [4/6], Loss: 0.0984, Val Loss: 0.2208, Val Accuracy: 0.9588, 99% Accuracy: 0.8499
# Epoch [5/6], Loss: 0.0223, Val Loss: 0.2319, Val Accuracy: 0.9561, 99% Accuracy: 0.8047
# Epoch [6/6], Loss: 0.7272, Val Loss: 0.2209, Val Accuracy: 0.9583, 99% Accuracy: 0.8494
# Best Loss: 0.07237015142505751
# Best Hyperparameters: {'layer1': 987, 'layer2': 661, 'dropout_rate': 0.32306500230368534, 'learning_rate': 7.644243621410023e-05}
# Number of learnable weights: 2405691
# Epoch [1/50], Loss: 0.0000, Val Loss: 0.1052, Val Accuracy: 0.9714, 99% Accuracy: 0.8587
# Epoch [2/50], Loss: 0.0007, Val Loss: 0.0916, Val Accuracy: 0.9728, 99% Accuracy: 0.8452
# Epoch [3/50], Loss: 0.0077, Val Loss: 0.0855, Val Accuracy: 0.9742, 99% Accuracy: 0.8466
# Epoch [4/50], Loss: 0.0066, Val Loss: 0.0768, Val Accuracy: 0.9780, 99% Accuracy: 0.8691
# Epoch [5/50], Loss: 0.0140, Val Loss: 0.0794, Val Accuracy: 0.9759, 99% Accuracy: 0.8667
# Epoch [6/50], Loss: 0.3695, Val Loss: 0.0792, Val Accuracy: 0.9780, 99% Accuracy: 0.8920
# Epoch [7/50], Loss: 0.0003, Val Loss: 0.0759, Val Accuracy: 0.9797, 99% Accuracy: 0.9038
# Epoch [8/50], Loss: 0.0094, Val Loss: 0.0647, Val Accuracy: 0.9815, 99% Accuracy: 0.8993
# Epoch [9/50], Loss: 0.0007, Val Loss: 0.0670, Val Accuracy: 0.9829, 99% Accuracy: 0.9093
# Epoch [10/50], Loss: 0.0000, Val Loss: 0.0659, Val Accuracy: 0.9826, 99% Accuracy: 0.9125
# Epoch [11/50], Loss: 0.0078, Val Loss: 0.0604, Val Accuracy: 0.9838, 99% Accuracy: 0.9147
# Epoch [12/50], Loss: 0.0001, Val Loss: 0.0600, Val Accuracy: 0.9849, 99% Accuracy: 0.9212
# Epoch [13/50], Loss: 0.0011, Val Loss: 0.0654, Val Accuracy: 0.9854, 99% Accuracy: 0.9242
# Epoch [14/50], Loss: 0.0131, Val Loss: 0.0591, Val Accuracy: 0.9859, 99% Accuracy: 0.9296
# Epoch [15/50], Loss: 0.0409, Val Loss: 0.0632, Val Accuracy: 0.9856, 99% Accuracy: 0.9305
# Epoch [16/50], Loss: 0.0000, Val Loss: 0.0659, Val Accuracy: 0.9859, 99% Accuracy: 0.9364
# Epoch [17/50], Loss: 0.0010, Val Loss: 0.0673, Val Accuracy: 0.9854, 99% Accuracy: 0.9386
# Epoch [18/50], Loss: 0.0025, Val Loss: 0.0641, Val Accuracy: 0.9863, 99% Accuracy: 0.9362
# Epoch [19/50], Loss: 0.0277, Val Loss: 0.0720, Val Accuracy: 0.9854, 99% Accuracy: 0.9445
# Epoch [20/50], Loss: 0.0000, Val Loss: 0.0657, Val Accuracy: 0.9871, 99% Accuracy: 0.9435
# Epoch [21/50], Loss: 0.0102, Val Loss: 0.0624, Val Accuracy: 0.9884, 99% Accuracy: 0.9488
# Epoch [22/50], Loss: 0.0000, Val Loss: 0.0789, Val Accuracy: 0.9872, 99% Accuracy: 0.9535
# Epoch [23/50], Loss: 0.0000, Val Loss: 0.0642, Val Accuracy: 0.9894, 99% Accuracy: 0.9573
# Epoch [24/50], Loss: 0.0000, Val Loss: 0.0643, Val Accuracy: 0.9894, 99% Accuracy: 0.9491
# Epoch [25/50], Loss: 0.0000, Val Loss: 0.0687, Val Accuracy: 0.9888, 99% Accuracy: 0.9568
# Epoch [26/50], Loss: 0.0000, Val Loss: 0.0753, Val Accuracy: 0.9893, 99% Accuracy: 0.9639
# Epoch [27/50], Loss: 0.0002, Val Loss: 0.0679, Val Accuracy: 0.9902, 99% Accuracy: 0.9640
# Epoch [28/50], Loss: 0.0000, Val Loss: 0.0705, Val Accuracy: 0.9897, 99% Accuracy: 0.9602
# Epoch [29/50], Loss: 0.0000, Val Loss: 0.0692, Val Accuracy: 0.9912, 99% Accuracy: 0.9639
# Epoch [30/50], Loss: 0.0000, Val Loss: 0.0729, Val Accuracy: 0.9908, 99% Accuracy: 0.9665
# Epoch [31/50], Loss: 0.0000, Val Loss: 0.0685, Val Accuracy: 0.9907, 99% Accuracy: 0.9615
# Epoch [32/50], Loss: 0.0000, Val Loss: 0.0813, Val Accuracy: 0.9904, 99% Accuracy: 0.9686
# Epoch [33/50], Loss: 0.0001, Val Loss: 0.0723, Val Accuracy: 0.9909, 99% Accuracy: 0.9683
# Epoch [34/50], Loss: 0.0093, Val Loss: 0.0759, Val Accuracy: 0.9913, 99% Accuracy: 0.9660
# Epoch [35/50], Loss: 0.1025, Val Loss: 0.0832, Val Accuracy: 0.9911, 99% Accuracy: 0.9675
# Epoch [36/50], Loss: 0.0000, Val Loss: 0.0799, Val Accuracy: 0.9914, 99% Accuracy: 0.9718
# Epoch [37/50], Loss: 0.0000, Val Loss: 0.0808, Val Accuracy: 0.9909, 99% Accuracy: 0.9688
# Epoch [38/50], Loss: 0.0000, Val Loss: 0.0768, Val Accuracy: 0.9912, 99% Accuracy: 0.9717
# Epoch [39/50], Loss: 0.0000, Val Loss: 0.0870, Val Accuracy: 0.9912, 99% Accuracy: 0.9742
# Epoch [40/50], Loss: 0.0000, Val Loss: 0.0845, Val Accuracy: 0.9919, 99% Accuracy: 0.9757
# Epoch [41/50], Loss: 0.0000, Val Loss: 0.0901, Val Accuracy: 0.9911, 99% Accuracy: 0.9675
# Epoch [42/50], Loss: 0.0000, Val Loss: 0.0822, Val Accuracy: 0.9922, 99% Accuracy: 0.9751
# Epoch [43/50], Loss: 0.0001, Val Loss: 0.0803, Val Accuracy: 0.9921, 99% Accuracy: 0.9726
# Epoch [44/50], Loss: 0.0000, Val Loss: 0.0872, Val Accuracy: 0.9921, 99% Accuracy: 0.9747
# Epoch [45/50], Loss: 0.0000, Val Loss: 0.0879, Val Accuracy: 0.9919, 99% Accuracy: 0.9756
# Epoch [46/50], Loss: 0.0000, Val Loss: 0.0870, Val Accuracy: 0.9929, 99% Accuracy: 0.9786
# Epoch [47/50], Loss: 0.0001, Val Loss: 0.0899, Val Accuracy: 0.9924, 99% Accuracy: 0.9767
# Epoch [48/50], Loss: 0.0000, Val Loss: 0.0979, Val Accuracy: 0.9917, 99% Accuracy: 0.9804
# Epoch [49/50], Loss: 0.0000, Val Loss: 0.1012, Val Accuracy: 0.9920, 99% Accuracy: 0.9780
# Epoch [50/50], Loss: 0.0000, Val Loss: 0.0903, Val Accuracy: 0.9932, 99% Accuracy: 0.9794
#
# --- BigBasket_category_ Default Metrics ---
# Accuracy: 0.993
# Precision: 0.988
# Recall: 0.977
# F1 Score: 0.982
# Adjusted Accuracy: 0.993
# Image Coverage: 1.0
# Brand Coverage: 1.0
#
# --- BigBasket_category_ 95% Metrics ---
# Accuracy: 0.987
# Precision: 0.9
# Recall: 0.876
# F1 Score: 0.888
# Adjusted Accuracy: 0.995
# Image Coverage: 0.992
# Brand Coverage: 1.0
#
# --- BigBasket_category_ 96% Metrics ---
# Accuracy: 0.986
# Precision: 0.9
# Recall: 0.876
# F1 Score: 0.887
# Adjusted Accuracy: 0.995
# Image Coverage: 0.991
# Brand Coverage: 1.0
#
# --- BigBasket_category_ 97% Metrics ---
# Accuracy: 0.985
# Precision: 0.9
# Recall: 0.872
# F1 Score: 0.886
# Adjusted Accuracy: 0.995
# Image Coverage: 0.989
# Brand Coverage: 1.0
#
# --- BigBasket_category_ 98% Metrics ---
# Accuracy: 0.983
# Precision: 0.9
# Recall: 0.87
# F1 Score: 0.885
# Adjusted Accuracy: 0.996
# Image Coverage: 0.987
# Brand Coverage: 1.0
#
# --- BigBasket_category_ 99% Metrics ---
# Accuracy: 0.979
# Precision: 0.904
# Recall: 0.868
# F1 Score: 0.886
# Adjusted Accuracy: 0.996
# Image Coverage: 0.983
# Brand Coverage: 1.0
# Metrics and definitions saved to BigBasket_Category_train_logs_2024-11-17_04-13_PM\BigBasket_category_metrics_output.xlsx

# %% [markdown]
# #### Brand classifiers

# %%
for category_id in range(train_num_master_cat):

    train_mask = (train_y_master_cat == category_id)
    test_mask = (test_y_master_cat == category_id)

    # Select only the relevant data based on the masks
    category_train_data = train_data[train_mask]
    category_train_y_brand = train_y_brand[train_mask]
    category_test_data = test_data[test_mask]
    category_test_y_brand = test_y_brand[test_mask]

    brand_dataset_train = SimpleDataset(category_train_data, category_train_y_brand)
    brand_dataloader_train = DataLoader(brand_dataset_train, batch_size=BATCH_SIZE, shuffle=True)
    brand_dataset_test = SimpleDataset(category_test_data, category_test_y_brand)
    brand_dataloader_test = DataLoader(brand_dataset_test, batch_size=BATCH_SIZE, shuffle=False)

    # Perform hyperparameter tuning specifically for this category
    best_model, best_params, best_loss = random_search(brand_dataloader_train, brand_dataloader_test, train_num_brands, n_trials=6, epochs=6, k=1)
    print(f"Category: {category_id} | Best Loss: {best_loss}")
    print(f"Category: {category_id} | Best Hyperparameters: {best_params}")
    
    # Define a title and directory for saving logs for this category
    train_log_title = f"{dataset_title}Category_{category_id}"
    save_directory = f"{train_log_title}_train_logs_{current_time}"

    # Initialize the model for this category with the best hyperparameters
    embedding_size = train_data.shape[1]  # assuming all categories share the same input feature size
    model_brand = classifierNN(
        embedding_size, 
        train_num_brands, 
        layer1=best_params['layer1'], 
        layer2=best_params['layer2'], 
        dropout_rate=best_params['dropout_rate'], 
        lr=best_params['learning_rate']
    )
    
    model_brand.to(device)
    num_weights = sum(p.numel() for p in model_brand.parameters() if p.requires_grad)
    print(f"Category: {category_id} | Number of learnable weights: {num_weights}")

    # Train the model for this category and enable logging
    model_brand.train_model(
        brand_dataloader_train, 
        brand_dataloader_test, 
        num_epochs=50,
        k=1, 
        save_directory=save_directory, 
        log_file=logfilepath
    )
    model_path = os.path.join(save_directory, weights_file_name)
    model_paths.append(model_path)

    # Evaluate the model for this category
    logits_brand, loss_brand, accuracy_brand, strict_accuracy_brand = model_brand.evaluate(brand_dataloader_test)
    logits_brand = logits_brand.cpu().numpy()

    file_name = f"{train_log_title}_brand"
    file_name = file_name + '_' if file_name else ''
    file_path = f'{save_directory}\\{file_name}metrics_output.xlsx'
    evaluate_and_save_model_stats(logits_brand, category_test_y_brand, metrics_title=file_name, file_path=file_path, print_metrics=False)
# Out:
# --- Params (iter 1) ---
# layer1: 127, layer2: 865, dropout: 0.07366600739227883, learning_rate: 6.514348921701892e-06
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\2680378259.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels, dtype=torch.float32)
# Epoch [1/6], Loss: 8.2408, Val Loss: 8.1287, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 8.2303, Val Loss: 8.1132, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 8.1408, Val Loss: 8.0974, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 8.0961, Val Loss: 8.0816, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 8.0640, Val Loss: 8.0658, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 8.0040, Val Loss: 8.0499, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# --- Params (iter 2) ---
# layer1: 523, layer2: 366, dropout: 0.19982606102245887, learning_rate: 0.0007230589052896631
# Epoch [1/6], Loss: 7.1351, Val Loss: 5.0889, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 2.3054, Val Loss: 2.5878, Val Accuracy: 0.6000, 99% Accuracy: 0.2000
# Epoch [3/6], Loss: 3.6109, Val Loss: 2.1144, Val Accuracy: 0.6000, 99% Accuracy: 0.6000
# Epoch [4/6], Loss: 1.4411, Val Loss: 0.4566, Val Accuracy: 0.8000, 99% Accuracy: 0.4000
# Epoch [5/6], Loss: 0.3778, Val Loss: 0.3259, Val Accuracy: 1.0000, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 0.7257, Val Loss: 0.2757, Val Accuracy: 1.0000, 99% Accuracy: 0.0000
# --- Params (iter 3) ---
# layer1: 132, layer2: 260, dropout: 0.25797431194839, learning_rate: 0.000766893633739744
# Epoch [1/6], Loss: 8.1210, Val Loss: 7.3589, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 7.1931, Val Loss: 5.8395, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 4.7073, Val Loss: 3.6303, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 2.9461, Val Loss: 2.1781, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 1.3665, Val Loss: 1.9393, Val Accuracy: 0.6000, 99% Accuracy: 0.4000
# Epoch [6/6], Loss: 1.1706, Val Loss: 1.4247, Val Accuracy: 0.6000, 99% Accuracy: 0.6000
# --- Params (iter 4) ---
# layer1: 270, layer2: 317, dropout: 0.1610098630870752, learning_rate: 0.00034302007021715976
# Epoch [1/6], Loss: 7.6930, Val Loss: 7.2387, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 6.7661, Val Loss: 6.0485, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 4.7977, Val Loss: 4.4535, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 3.4220, Val Loss: 2.7975, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 2.1915, Val Loss: 2.0821, Val Accuracy: 0.6000, 99% Accuracy: 0.2000
# Epoch [6/6], Loss: 3.1461, Val Loss: 1.8206, Val Accuracy: 0.6000, 99% Accuracy: 0.4000
# --- Params (iter 5) ---
# layer1: 564, layer2: 338, dropout: 0.2895835707218854, learning_rate: 0.00013036451438017593
# Epoch [1/6], Loss: 7.6934, Val Loss: 7.4591, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 7.3730, Val Loss: 6.7649, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 6.4331, Val Loss: 5.9946, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 5.4192, Val Loss: 5.1104, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 4.8876, Val Loss: 4.1411, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 3.3662, Val Loss: 3.2610, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# --- Params (iter 6) ---
# layer1: 423, layer2: 450, dropout: 0.2966444414684122, learning_rate: 8.54075095916373e-06
# Epoch [1/6], Loss: 8.3125, Val Loss: 8.2764, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 8.3329, Val Loss: 8.2364, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 8.2060, Val Loss: 8.1971, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 8.1861, Val Loss: 8.1594, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 8.1923, Val Loss: 8.1225, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 8.0495, Val Loss: 8.0855, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Category: 0 | Best Loss: 0.275709331035614
# Category: 0 | Best Hyperparameters: {'layer1': 523, 'layer2': 366, 'dropout_rate': 0.19982606102245887, 'learning_rate': 0.0007230589052896631}
# Category: 0 | Number of learnable weights: 2545335
# Epoch [1/50], Loss: 6.4949, Val Loss: 4.8399, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [2/50], Loss: 2.6121, Val Loss: 2.4521, Val Accuracy: 0.6000, 99% Accuracy: 0.4000
# Epoch [3/50], Loss: 2.8880, Val Loss: 1.9858, Val Accuracy: 0.6000, 99% Accuracy: 0.6000
# Epoch [4/50], Loss: 2.6095, Val Loss: 0.4441, Val Accuracy: 0.6000, 99% Accuracy: 0.6000
# Epoch [5/50], Loss: 0.3700, Val Loss: 0.6064, Val Accuracy: 0.6000, 99% Accuracy: 0.0000
# Epoch [6/50], Loss: 0.5844, Val Loss: 0.3330, Val Accuracy: 1.0000, 99% Accuracy: 0.0000
# Epoch [7/50], Loss: 0.0854, Val Loss: 0.1382, Val Accuracy: 1.0000, 99% Accuracy: 0.2000
# Epoch [8/50], Loss: 0.0135, Val Loss: 0.1252, Val Accuracy: 1.0000, 99% Accuracy: 0.4000
# Epoch [9/50], Loss: 0.0618, Val Loss: 0.0847, Val Accuracy: 1.0000, 99% Accuracy: 0.6000
# Epoch [10/50], Loss: 0.0424, Val Loss: 0.0491, Val Accuracy: 1.0000, 99% Accuracy: 0.6000
# Epoch [11/50], Loss: 0.0110, Val Loss: 0.0238, Val Accuracy: 1.0000, 99% Accuracy: 0.6000
# Epoch [12/50], Loss: 0.0178, Val Loss: 0.0133, Val Accuracy: 1.0000, 99% Accuracy: 0.6000
# Epoch [13/50], Loss: 0.0154, Val Loss: 0.0083, Val Accuracy: 1.0000, 99% Accuracy: 0.8000
# Epoch [14/50], Loss: 0.0020, Val Loss: 0.0041, Val Accuracy: 1.0000, 99% Accuracy: 0.8000
# Epoch [15/50], Loss: 0.0123, Val Loss: 0.0019, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [16/50], Loss: 0.0010, Val Loss: 0.0010, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [17/50], Loss: 0.0009, Val Loss: 0.0006, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [18/50], Loss: 0.0036, Val Loss: 0.0004, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [19/50], Loss: 0.0011, Val Loss: 0.0003, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [20/50], Loss: 0.0011, Val Loss: 0.0002, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [21/50], Loss: 0.0025, Val Loss: 0.0002, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [22/50], Loss: 0.0002, Val Loss: 0.0002, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [23/50], Loss: 0.0003, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [24/50], Loss: 0.0009, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [25/50], Loss: 0.0015, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [26/50], Loss: 0.0001, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [27/50], Loss: 0.0004, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [28/50], Loss: 0.0003, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [29/50], Loss: 0.0006, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [30/50], Loss: 0.0002, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [31/50], Loss: 0.0002, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [32/50], Loss: 0.0007, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [33/50], Loss: 0.0002, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [34/50], Loss: 0.0005, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [35/50], Loss: 0.0001, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [36/50], Loss: 0.0004, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [37/50], Loss: 0.0001, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [38/50], Loss: 0.0001, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [39/50], Loss: 0.0005, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [40/50], Loss: 0.0001, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [41/50], Loss: 0.0001, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [42/50], Loss: 0.0001, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [43/50], Loss: 0.0001, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [44/50], Loss: 0.0002, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [45/50], Loss: 0.0004, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [46/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [47/50], Loss: 0.0001, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [48/50], Loss: 0.0003, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [49/50], Loss: 0.0002, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [50/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Metrics and definitions saved to BigBasket_Category_0_train_logs_2024-11-17_04-13_PM\BigBasket_Category_0_brand_metrics_output.xlsx
# --- Params (iter 1) ---
# layer1: 651, layer2: 966, dropout: 0.18410418285353758, learning_rate: 0.0005834773208603497
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\2680378259.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels, dtype=torch.float32)
# Epoch [1/6], Loss: 1.9271, Val Loss: 2.1707, Val Accuracy: 0.5294, 99% Accuracy: 0.0980
# Epoch [2/6], Loss: 0.4547, Val Loss: 0.9309, Val Accuracy: 0.7647, 99% Accuracy: 0.1373
# Epoch [3/6], Loss: 0.2248, Val Loss: 0.5847, Val Accuracy: 0.8235, 99% Accuracy: 0.1961
# Epoch [4/6], Loss: 0.3165, Val Loss: 0.3174, Val Accuracy: 0.9020, 99% Accuracy: 0.2157
# Epoch [5/6], Loss: 0.2661, Val Loss: 0.2544, Val Accuracy: 0.9412, 99% Accuracy: 0.4118
# Epoch [6/6], Loss: 0.4019, Val Loss: 0.1832, Val Accuracy: 0.9608, 99% Accuracy: 0.3725
# --- Params (iter 2) ---
# layer1: 227, layer2: 661, dropout: 0.22292099696495343, learning_rate: 0.003821527302871806
# Epoch [1/6], Loss: 2.1631, Val Loss: 2.2601, Val Accuracy: 0.4706, 99% Accuracy: 0.0980
# Epoch [2/6], Loss: 2.8092, Val Loss: 1.3939, Val Accuracy: 0.6863, 99% Accuracy: 0.2157
# Epoch [3/6], Loss: 2.5752, Val Loss: 0.8687, Val Accuracy: 0.7843, 99% Accuracy: 0.1176
# Epoch [4/6], Loss: 1.1583, Val Loss: 0.5225, Val Accuracy: 0.8039, 99% Accuracy: 0.3137
# Epoch [5/6], Loss: 0.0219, Val Loss: 0.3163, Val Accuracy: 0.9020, 99% Accuracy: 0.4510
# Epoch [6/6], Loss: 0.0460, Val Loss: 0.5605, Val Accuracy: 0.8431, 99% Accuracy: 0.4902
# --- Params (iter 3) ---
# layer1: 597, layer2: 141, dropout: 0.3780928837264585, learning_rate: 0.00042754232875394377
# Epoch [1/6], Loss: 6.7403, Val Loss: 4.0714, Val Accuracy: 0.3725, 99% Accuracy: 0.1176
# Epoch [2/6], Loss: 3.0803, Val Loss: 2.1569, Val Accuracy: 0.6078, 99% Accuracy: 0.0196
# Epoch [3/6], Loss: 0.5288, Val Loss: 1.4389, Val Accuracy: 0.6275, 99% Accuracy: 0.2157
# Epoch [4/6], Loss: 1.1409, Val Loss: 1.0389, Val Accuracy: 0.6863, 99% Accuracy: 0.1765
# Epoch [5/6], Loss: 0.0584, Val Loss: 0.8101, Val Accuracy: 0.7647, 99% Accuracy: 0.2941
# Epoch [6/6], Loss: 0.2334, Val Loss: 0.6708, Val Accuracy: 0.7451, 99% Accuracy: 0.2157
# --- Params (iter 4) ---
# layer1: 937, layer2: 403, dropout: 0.34727582148596464, learning_rate: 0.008200634434383897
# Epoch [1/6], Loss: 4.5190, Val Loss: 2.0864, Val Accuracy: 0.5490, 99% Accuracy: 0.2941
# Epoch [2/6], Loss: 1.1978, Val Loss: 1.2449, Val Accuracy: 0.6471, 99% Accuracy: 0.2941
# Epoch [3/6], Loss: 0.5407, Val Loss: 0.9119, Val Accuracy: 0.7647, 99% Accuracy: 0.2745
# Epoch [4/6], Loss: 0.9053, Val Loss: 0.9523, Val Accuracy: 0.7255, 99% Accuracy: 0.2941
# Epoch [5/6], Loss: 0.4388, Val Loss: 0.9130, Val Accuracy: 0.7843, 99% Accuracy: 0.5882
# Epoch [6/6], Loss: 2.1022, Val Loss: 0.9286, Val Accuracy: 0.6863, 99% Accuracy: 0.4706
# --- Params (iter 5) ---
# layer1: 872, layer2: 971, dropout: 0.061737527092829286, learning_rate: 1.4669683382773012e-06
# Epoch [1/6], Loss: 8.2175, Val Loss: 8.2599, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 8.2119, Val Loss: 8.2252, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 8.2986, Val Loss: 8.1917, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 8.0638, Val Loss: 8.1599, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 8.1263, Val Loss: 8.1262, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 8.1275, Val Loss: 8.0917, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# --- Params (iter 6) ---
# layer1: 357, layer2: 129, dropout: 0.38263891326023247, learning_rate: 0.0006662829966580836
# Epoch [1/6], Loss: 5.9247, Val Loss: 4.0277, Val Accuracy: 0.3725, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 1.1823, Val Loss: 2.1455, Val Accuracy: 0.5686, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 3.1225, Val Loss: 1.5568, Val Accuracy: 0.5490, 99% Accuracy: 0.2157
# Epoch [4/6], Loss: 0.5765, Val Loss: 1.0979, Val Accuracy: 0.6667, 99% Accuracy: 0.2157
# Epoch [5/6], Loss: 1.4211, Val Loss: 0.9969, Val Accuracy: 0.7059, 99% Accuracy: 0.2353
# Epoch [6/6], Loss: 0.6603, Val Loss: 0.7272, Val Accuracy: 0.8039, 99% Accuracy: 0.2353
# Category: 1 | Best Loss: 0.18315910396631807
# Category: 1 | Best Hyperparameters: {'layer1': 651, 'layer2': 966, 'dropout_rate': 0.18410418285353758, 'learning_rate': 0.0005834773208603497}
# Category: 1 | Number of learnable weights: 5545015
# Epoch [1/50], Loss: 1.6880, Val Loss: 1.9585, Val Accuracy: 0.5294, 99% Accuracy: 0.2157
# Epoch [2/50], Loss: 1.5418, Val Loss: 1.0124, Val Accuracy: 0.7451, 99% Accuracy: 0.0000
# Epoch [3/50], Loss: 0.3195, Val Loss: 0.6823, Val Accuracy: 0.7647, 99% Accuracy: 0.2549
# Epoch [4/50], Loss: 0.6203, Val Loss: 0.5035, Val Accuracy: 0.8039, 99% Accuracy: 0.3333
# Epoch [5/50], Loss: 0.1678, Val Loss: 0.2869, Val Accuracy: 0.9020, 99% Accuracy: 0.4118
# Epoch [6/50], Loss: 0.0526, Val Loss: 0.1922, Val Accuracy: 0.9412, 99% Accuracy: 0.3529
# Epoch [7/50], Loss: 0.2241, Val Loss: 0.0889, Val Accuracy: 0.9804, 99% Accuracy: 0.3529
# Epoch [8/50], Loss: 0.0262, Val Loss: 0.1412, Val Accuracy: 0.9412, 99% Accuracy: 0.5098
# Epoch [9/50], Loss: 0.0472, Val Loss: 0.0653, Val Accuracy: 1.0000, 99% Accuracy: 0.5882
# Epoch [10/50], Loss: 0.0100, Val Loss: 0.0576, Val Accuracy: 1.0000, 99% Accuracy: 0.6078
# Epoch [11/50], Loss: 0.0004, Val Loss: 0.0365, Val Accuracy: 0.9804, 99% Accuracy: 0.6667
# Epoch [12/50], Loss: 0.6463, Val Loss: 0.0453, Val Accuracy: 0.9804, 99% Accuracy: 0.6275
# Epoch [13/50], Loss: 0.0015, Val Loss: 0.1497, Val Accuracy: 0.9608, 99% Accuracy: 0.6471
# Epoch [14/50], Loss: 0.0068, Val Loss: 0.0490, Val Accuracy: 0.9804, 99% Accuracy: 0.6863
# Epoch [15/50], Loss: 0.2399, Val Loss: 0.0536, Val Accuracy: 0.9804, 99% Accuracy: 0.6471
# Epoch [16/50], Loss: 0.0230, Val Loss: 0.0368, Val Accuracy: 0.9804, 99% Accuracy: 0.6667
# Epoch [17/50], Loss: 0.0174, Val Loss: 0.0629, Val Accuracy: 0.9608, 99% Accuracy: 0.7451
# Epoch [18/50], Loss: 0.0014, Val Loss: 0.0290, Val Accuracy: 0.9804, 99% Accuracy: 0.8431
# Epoch [19/50], Loss: 0.0114, Val Loss: 0.0346, Val Accuracy: 0.9804, 99% Accuracy: 0.8039
# Epoch [20/50], Loss: 0.0011, Val Loss: 0.0230, Val Accuracy: 1.0000, 99% Accuracy: 0.8235
# Epoch [21/50], Loss: 0.0005, Val Loss: 0.0559, Val Accuracy: 0.9608, 99% Accuracy: 0.8431
# Epoch [22/50], Loss: 0.0002, Val Loss: 0.0213, Val Accuracy: 1.0000, 99% Accuracy: 0.8824
# Epoch [23/50], Loss: 0.0107, Val Loss: 0.0369, Val Accuracy: 0.9608, 99% Accuracy: 0.9020
# Epoch [24/50], Loss: 0.0304, Val Loss: 0.0361, Val Accuracy: 0.9608, 99% Accuracy: 0.9020
# Epoch [25/50], Loss: 0.0005, Val Loss: 0.0388, Val Accuracy: 0.9804, 99% Accuracy: 0.8824
# Epoch [26/50], Loss: 0.0043, Val Loss: 0.0645, Val Accuracy: 0.9804, 99% Accuracy: 0.8824
# Epoch [27/50], Loss: 0.1325, Val Loss: 0.0206, Val Accuracy: 1.0000, 99% Accuracy: 0.8627
# Epoch [28/50], Loss: 0.0008, Val Loss: 0.0714, Val Accuracy: 0.9804, 99% Accuracy: 0.9412
# Epoch [29/50], Loss: 0.0592, Val Loss: 0.0405, Val Accuracy: 0.9804, 99% Accuracy: 0.8431
# Epoch [30/50], Loss: 0.0002, Val Loss: 0.0224, Val Accuracy: 1.0000, 99% Accuracy: 0.9020
# Epoch [31/50], Loss: 0.0007, Val Loss: 0.0160, Val Accuracy: 1.0000, 99% Accuracy: 0.9020
# Epoch [32/50], Loss: 0.0004, Val Loss: 0.0107, Val Accuracy: 1.0000, 99% Accuracy: 0.9020
# Epoch [33/50], Loss: 0.0021, Val Loss: 0.0212, Val Accuracy: 0.9804, 99% Accuracy: 0.8824
# Epoch [34/50], Loss: 0.0002, Val Loss: 0.0112, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [35/50], Loss: 0.0000, Val Loss: 0.0114, Val Accuracy: 1.0000, 99% Accuracy: 0.9020
# Epoch [36/50], Loss: 0.0004, Val Loss: 0.0119, Val Accuracy: 1.0000, 99% Accuracy: 0.9020
# Epoch [37/50], Loss: 0.0006, Val Loss: 0.0096, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [38/50], Loss: 0.0005, Val Loss: 0.0080, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [39/50], Loss: 0.0001, Val Loss: 0.0078, Val Accuracy: 1.0000, 99% Accuracy: 0.9020
# Epoch [40/50], Loss: 0.0009, Val Loss: 0.0103, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [41/50], Loss: 0.0004, Val Loss: 0.0095, Val Accuracy: 1.0000, 99% Accuracy: 0.9020
# Epoch [42/50], Loss: 0.0001, Val Loss: 0.0063, Val Accuracy: 1.0000, 99% Accuracy: 0.9412
# Epoch [43/50], Loss: 0.0000, Val Loss: 0.0047, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [44/50], Loss: 0.0006, Val Loss: 0.0057, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [45/50], Loss: 0.0004, Val Loss: 0.0054, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [46/50], Loss: 0.0008, Val Loss: 0.0049, Val Accuracy: 1.0000, 99% Accuracy: 0.9412
# Epoch [47/50], Loss: 0.0001, Val Loss: 0.0049, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [48/50], Loss: 0.0000, Val Loss: 0.0044, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [49/50], Loss: 0.0003, Val Loss: 0.0039, Val Accuracy: 1.0000, 99% Accuracy: 0.9216
# Epoch [50/50], Loss: 0.0005, Val Loss: 0.0049, Val Accuracy: 1.0000, 99% Accuracy: 0.9412
# Metrics and definitions saved to BigBasket_Category_1_train_logs_2024-11-17_04-13_PM\BigBasket_Category_1_brand_metrics_output.xlsx
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\2680378259.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels, dtype=torch.float32)
# --- Params (iter 1) ---
# layer1: 486, layer2: 742, dropout: 0.2664383111032962, learning_rate: 1.1550927896490326e-06
# Epoch [1/6], Loss: 7.9400, Val Loss: 7.8260, Val Accuracy: 0.0299, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 6.5088, Val Loss: 6.6482, Val Accuracy: 0.0268, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 5.9299, Val Loss: 6.1447, Val Accuracy: 0.0685, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 5.4530, Val Loss: 5.8909, Val Accuracy: 0.0826, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 5.5223, Val Loss: 5.6957, Val Accuracy: 0.0975, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 6.4774, Val Loss: 5.5230, Val Accuracy: 0.1151, 99% Accuracy: 0.0000
# --- Params (iter 2) ---
# layer1: 845, layer2: 50, dropout: 0.3332904656345296, learning_rate: 0.0011188591059212813
# Epoch [1/6], Loss: 5.8453, Val Loss: 3.9528, Val Accuracy: 0.2492, 99% Accuracy: 0.0274
# Epoch [2/6], Loss: 3.2111, Val Loss: 3.5517, Val Accuracy: 0.2888, 99% Accuracy: 0.0503
# Epoch [3/6], Loss: 4.1471, Val Loss: 3.2518, Val Accuracy: 0.3400, 99% Accuracy: 0.0594
# Epoch [4/6], Loss: 5.0154, Val Loss: 3.1890, Val Accuracy: 0.3387, 99% Accuracy: 0.0681
# Epoch [5/6], Loss: 5.3627, Val Loss: 3.0624, Val Accuracy: 0.3531, 99% Accuracy: 0.0706
# Epoch [6/6], Loss: 4.2926, Val Loss: 3.0341, Val Accuracy: 0.3531, 99% Accuracy: 0.0801
# --- Params (iter 3) ---
# layer1: 804, layer2: 274, dropout: 0.15114447835068945, learning_rate: 0.0006627521675117747
# Epoch [1/6], Loss: 2.9545, Val Loss: 2.6088, Val Accuracy: 0.4534, 99% Accuracy: 0.0787
# Epoch [2/6], Loss: 1.9832, Val Loss: 2.0029, Val Accuracy: 0.5466, 99% Accuracy: 0.1251
# Epoch [3/6], Loss: 2.4942, Val Loss: 1.6786, Val Accuracy: 0.6061, 99% Accuracy: 0.1863
# Epoch [4/6], Loss: 1.6058, Val Loss: 1.5163, Val Accuracy: 0.6347, 99% Accuracy: 0.2355
# Epoch [5/6], Loss: 1.2025, Val Loss: 1.3500, Val Accuracy: 0.6725, 99% Accuracy: 0.2794
# Epoch [6/6], Loss: 0.8544, Val Loss: 1.2261, Val Accuracy: 0.7030, 99% Accuracy: 0.3184
# --- Params (iter 4) ---
# layer1: 961, layer2: 640, dropout: 0.27698792420564655, learning_rate: 2.9752275262333335e-06
# Epoch [1/6], Loss: 6.1602, Val Loss: 6.0410, Val Accuracy: 0.0765, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 5.2493, Val Loss: 5.3830, Val Accuracy: 0.1368, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 4.4766, Val Loss: 4.9575, Val Accuracy: 0.1744, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 4.7954, Val Loss: 4.6233, Val Accuracy: 0.2094, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 4.2547, Val Loss: 4.3512, Val Accuracy: 0.2363, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 4.3145, Val Loss: 4.1182, Val Accuracy: 0.2603, 99% Accuracy: 0.0000
# --- Params (iter 5) ---
# layer1: 447, layer2: 609, dropout: 0.1479061983286612, learning_rate: 1.4132850981282584e-06
# Epoch [1/6], Loss: 7.6177, Val Loss: 7.5379, Val Accuracy: 0.0311, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 6.5149, Val Loss: 6.3009, Val Accuracy: 0.0633, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 5.9267, Val Loss: 5.9126, Val Accuracy: 0.0993, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 5.4586, Val Loss: 5.6424, Val Accuracy: 0.1096, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 5.4337, Val Loss: 5.4119, Val Accuracy: 0.1238, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 5.7266, Val Loss: 5.2034, Val Accuracy: 0.1397, 99% Accuracy: 0.0000
# --- Params (iter 6) ---
# layer1: 680, layer2: 835, dropout: 0.32826246023319966, learning_rate: 0.00023533829367504292
# Epoch [1/6], Loss: 3.1201, Val Loss: 2.6980, Val Accuracy: 0.4516, 99% Accuracy: 0.0342
# Epoch [2/6], Loss: 3.8550, Val Loss: 1.9846, Val Accuracy: 0.5625, 99% Accuracy: 0.0812
# Epoch [3/6], Loss: 2.6390, Val Loss: 1.5752, Val Accuracy: 0.6356, 99% Accuracy: 0.1384
# Epoch [4/6], Loss: 0.8723, Val Loss: 1.3171, Val Accuracy: 0.6835, 99% Accuracy: 0.1851
# Epoch [5/6], Loss: 0.7656, Val Loss: 1.1407, Val Accuracy: 0.7184, 99% Accuracy: 0.2338
# Epoch [6/6], Loss: 1.9242, Val Loss: 1.0165, Val Accuracy: 0.7467, 99% Accuracy: 0.2610
# Category: 2 | Best Loss: 1.0165441530856607
# Category: 2 | Best Hyperparameters: {'layer1': 680, 'layer2': 835, 'dropout_rate': 0.32826246023319966, 'learning_rate': 0.00023533829367504292}
# Category: 2 | Number of learnable weights: 5025267
# Epoch [1/50], Loss: 4.0222, Val Loss: 2.6936, Val Accuracy: 0.4518, 99% Accuracy: 0.0270
# Epoch [2/50], Loss: 2.1549, Val Loss: 1.9698, Val Accuracy: 0.5621, 99% Accuracy: 0.0934
# Epoch [3/50], Loss: 1.3274, Val Loss: 1.5847, Val Accuracy: 0.6307, 99% Accuracy: 0.1329
# Epoch [4/50], Loss: 2.5615, Val Loss: 1.3165, Val Accuracy: 0.6859, 99% Accuracy: 0.1784
# Epoch [5/50], Loss: 0.8768, Val Loss: 1.1388, Val Accuracy: 0.7222, 99% Accuracy: 0.2266
# Epoch [6/50], Loss: 0.8402, Val Loss: 0.9987, Val Accuracy: 0.7513, 99% Accuracy: 0.2624
# Epoch [7/50], Loss: 0.7445, Val Loss: 0.9076, Val Accuracy: 0.7775, 99% Accuracy: 0.3077
# Epoch [8/50], Loss: 0.7743, Val Loss: 0.8233, Val Accuracy: 0.7948, 99% Accuracy: 0.3278
# Epoch [9/50], Loss: 0.9236, Val Loss: 0.7359, Val Accuracy: 0.8261, 99% Accuracy: 0.4026
# Epoch [10/50], Loss: 1.6774, Val Loss: 0.6557, Val Accuracy: 0.8434, 99% Accuracy: 0.4329
# Epoch [11/50], Loss: 0.1335, Val Loss: 0.6506, Val Accuracy: 0.8497, 99% Accuracy: 0.4509
# Epoch [12/50], Loss: 0.0956, Val Loss: 0.5987, Val Accuracy: 0.8628, 99% Accuracy: 0.4874
# Epoch [13/50], Loss: 0.5944, Val Loss: 0.5741, Val Accuracy: 0.8715, 99% Accuracy: 0.5101
# Epoch [14/50], Loss: 1.0110, Val Loss: 0.5483, Val Accuracy: 0.8798, 99% Accuracy: 0.5398
# Epoch [15/50], Loss: 0.4056, Val Loss: 0.5244, Val Accuracy: 0.8902, 99% Accuracy: 0.5596
# Epoch [16/50], Loss: 0.1083, Val Loss: 0.5117, Val Accuracy: 0.8965, 99% Accuracy: 0.5814
# Epoch [17/50], Loss: 0.4442, Val Loss: 0.5206, Val Accuracy: 0.8970, 99% Accuracy: 0.5989
# Epoch [18/50], Loss: 0.4923, Val Loss: 0.5146, Val Accuracy: 0.8999, 99% Accuracy: 0.6181
# Epoch [19/50], Loss: 0.1263, Val Loss: 0.4839, Val Accuracy: 0.9089, 99% Accuracy: 0.6317
# Epoch [20/50], Loss: 0.6087, Val Loss: 0.4888, Val Accuracy: 0.9107, 99% Accuracy: 0.6359
# Epoch [21/50], Loss: 0.1802, Val Loss: 0.4684, Val Accuracy: 0.9203, 99% Accuracy: 0.6651
# Epoch [22/50], Loss: 0.2412, Val Loss: 0.4860, Val Accuracy: 0.9174, 99% Accuracy: 0.6852
# Epoch [23/50], Loss: 0.0674, Val Loss: 0.4758, Val Accuracy: 0.9212, 99% Accuracy: 0.7034
# Epoch [24/50], Loss: 0.1797, Val Loss: 0.4715, Val Accuracy: 0.9266, 99% Accuracy: 0.7073
# Epoch [25/50], Loss: 0.1440, Val Loss: 0.5020, Val Accuracy: 0.9259, 99% Accuracy: 0.7185
# Epoch [26/50], Loss: 0.3132, Val Loss: 0.4926, Val Accuracy: 0.9236, 99% Accuracy: 0.7259
# Epoch [27/50], Loss: 0.8640, Val Loss: 0.4992, Val Accuracy: 0.9265, 99% Accuracy: 0.7339
# Epoch [28/50], Loss: 0.3193, Val Loss: 0.5059, Val Accuracy: 0.9288, 99% Accuracy: 0.7555
# Epoch [29/50], Loss: 0.5337, Val Loss: 0.4855, Val Accuracy: 0.9320, 99% Accuracy: 0.7533
# Epoch [30/50], Loss: 0.2060, Val Loss: 0.5127, Val Accuracy: 0.9294, 99% Accuracy: 0.7621
# Epoch [31/50], Loss: 0.0149, Val Loss: 0.5136, Val Accuracy: 0.9327, 99% Accuracy: 0.7652
# Epoch [32/50], Loss: 0.1355, Val Loss: 0.5000, Val Accuracy: 0.9395, 99% Accuracy: 0.7875
# Epoch [33/50], Loss: 0.0919, Val Loss: 0.5495, Val Accuracy: 0.9357, 99% Accuracy: 0.7893
# Epoch [34/50], Loss: 0.2901, Val Loss: 0.5299, Val Accuracy: 0.9368, 99% Accuracy: 0.7851
# Epoch [35/50], Loss: 0.0576, Val Loss: 0.5356, Val Accuracy: 0.9377, 99% Accuracy: 0.7963
# Epoch [36/50], Loss: 0.3663, Val Loss: 0.5240, Val Accuracy: 0.9354, 99% Accuracy: 0.7972
# Epoch [37/50], Loss: 0.0002, Val Loss: 0.5228, Val Accuracy: 0.9412, 99% Accuracy: 0.8092
# Epoch [38/50], Loss: 0.0139, Val Loss: 0.5296, Val Accuracy: 0.9367, 99% Accuracy: 0.8126
# Epoch [39/50], Loss: 0.0361, Val Loss: 0.5542, Val Accuracy: 0.9367, 99% Accuracy: 0.8155
# Epoch [40/50], Loss: 0.0344, Val Loss: 0.5278, Val Accuracy: 0.9414, 99% Accuracy: 0.8237
# Epoch [41/50], Loss: 0.1205, Val Loss: 0.5369, Val Accuracy: 0.9426, 99% Accuracy: 0.8261
# Epoch [42/50], Loss: 1.1568, Val Loss: 0.5571, Val Accuracy: 0.9389, 99% Accuracy: 0.8266
# Epoch [43/50], Loss: 0.0009, Val Loss: 0.5552, Val Accuracy: 0.9395, 99% Accuracy: 0.8210
# Epoch [44/50], Loss: 0.0740, Val Loss: 0.5866, Val Accuracy: 0.9412, 99% Accuracy: 0.8430
# Epoch [45/50], Loss: 0.0025, Val Loss: 0.5901, Val Accuracy: 0.9389, 99% Accuracy: 0.8327
# Epoch [46/50], Loss: 1.0548, Val Loss: 0.5754, Val Accuracy: 0.9425, 99% Accuracy: 0.8430
# Epoch [47/50], Loss: 0.0045, Val Loss: 0.6078, Val Accuracy: 0.9435, 99% Accuracy: 0.8489
# Epoch [48/50], Loss: 0.2608, Val Loss: 0.6182, Val Accuracy: 0.9440, 99% Accuracy: 0.8495
# Epoch [49/50], Loss: 2.3033, Val Loss: 0.6460, Val Accuracy: 0.9440, 99% Accuracy: 0.8567
# Epoch [50/50], Loss: 0.4233, Val Loss: 0.6306, Val Accuracy: 0.9416, 99% Accuracy: 0.8505
# c:\Users\Austin\anaconda3\envs\condaenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics and definitions saved to BigBasket_Category_2_train_logs_2024-11-17_04-13_PM\BigBasket_Category_2_brand_metrics_output.xlsx
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\2680378259.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels, dtype=torch.float32)
# --- Params (iter 1) ---
# layer1: 157, layer2: 234, dropout: 0.27722250566132517, learning_rate: 0.005484473914146054
# Epoch [1/6], Loss: 5.7328, Val Loss: 4.7768, Val Accuracy: 0.1196, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 4.1103, Val Loss: 4.6060, Val Accuracy: 0.1383, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 5.8277, Val Loss: 4.3502, Val Accuracy: 0.1294, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 5.0902, Val Loss: 4.1609, Val Accuracy: 0.1424, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 4.5249, Val Loss: 4.1481, Val Accuracy: 0.1522, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 4.6405, Val Loss: 4.1063, Val Accuracy: 0.1416, 99% Accuracy: 0.0081
# --- Params (iter 2) ---
# layer1: 198, layer2: 536, dropout: 0.3974272602014326, learning_rate: 0.00021762347429061399
# Epoch [1/6], Loss: 4.1849, Val Loss: 4.2540, Val Accuracy: 0.2514, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 1.8467, Val Loss: 3.1019, Val Accuracy: 0.4125, 99% Accuracy: 0.0016
# Epoch [3/6], Loss: 2.9213, Val Loss: 2.3821, Val Accuracy: 0.5452, 99% Accuracy: 0.0016
# Epoch [4/6], Loss: 1.1067, Val Loss: 1.8749, Val Accuracy: 0.6257, 99% Accuracy: 0.0098
# Epoch [5/6], Loss: 2.9679, Val Loss: 1.5391, Val Accuracy: 0.6794, 99% Accuracy: 0.0179
# Epoch [6/6], Loss: 1.9175, Val Loss: 1.2676, Val Accuracy: 0.7404, 99% Accuracy: 0.0480
# --- Params (iter 3) ---
# layer1: 457, layer2: 414, dropout: 0.14222120312866993, learning_rate: 0.0035355684946704906
# Epoch [1/6], Loss: 4.9501, Val Loss: 3.7026, Val Accuracy: 0.2823, 99% Accuracy: 0.0407
# Epoch [2/6], Loss: 3.6909, Val Loss: 2.9636, Val Accuracy: 0.3483, 99% Accuracy: 0.0553
# Epoch [3/6], Loss: 3.0475, Val Loss: 2.6474, Val Accuracy: 0.4125, 99% Accuracy: 0.0789
# Epoch [4/6], Loss: 3.6901, Val Loss: 2.6807, Val Accuracy: 0.4093, 99% Accuracy: 0.0708
# Epoch [5/6], Loss: 2.1354, Val Loss: 2.3784, Val Accuracy: 0.4654, 99% Accuracy: 0.0993
# Epoch [6/6], Loss: 3.1792, Val Loss: 2.3101, Val Accuracy: 0.4646, 99% Accuracy: 0.0740
# --- Params (iter 4) ---
# layer1: 393, layer2: 663, dropout: 0.34440286772484946, learning_rate: 3.366115539984543e-05
# Epoch [1/6], Loss: 5.5203, Val Loss: 5.0913, Val Accuracy: 0.1481, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 4.4590, Val Loss: 4.2988, Val Accuracy: 0.2571, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 4.0082, Val Loss: 3.7675, Val Accuracy: 0.2897, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 4.2151, Val Loss: 3.3195, Val Accuracy: 0.3751, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 3.1523, Val Loss: 2.9607, Val Accuracy: 0.4174, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 3.9362, Val Loss: 2.6301, Val Accuracy: 0.4679, 99% Accuracy: 0.0000
# --- Params (iter 5) ---
# layer1: 861, layer2: 584, dropout: 0.39629862307720376, learning_rate: 0.00013774009221106362
# Epoch [1/6], Loss: 5.9086, Val Loss: 3.8336, Val Accuracy: 0.3214, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 3.2337, Val Loss: 2.6570, Val Accuracy: 0.4801, 99% Accuracy: 0.0008
# Epoch [3/6], Loss: 1.3740, Val Loss: 1.9509, Val Accuracy: 0.6184, 99% Accuracy: 0.0114
# Epoch [4/6], Loss: 1.9053, Val Loss: 1.4617, Val Accuracy: 0.7030, 99% Accuracy: 0.0456
# Epoch [5/6], Loss: 1.3202, Val Loss: 1.1137, Val Accuracy: 0.7681, 99% Accuracy: 0.0806
# Epoch [6/6], Loss: 0.6125, Val Loss: 0.9069, Val Accuracy: 0.8055, 99% Accuracy: 0.1221
# --- Params (iter 6) ---
# layer1: 1014, layer2: 208, dropout: 0.30276111895219093, learning_rate: 0.00027292587500878367
# Epoch [1/6], Loss: 3.3542, Val Loss: 3.5309, Val Accuracy: 0.3775, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 3.6911, Val Loss: 2.3174, Val Accuracy: 0.5378, 99% Accuracy: 0.0179
# Epoch [3/6], Loss: 1.6834, Val Loss: 1.6506, Val Accuracy: 0.6607, 99% Accuracy: 0.0342
# Epoch [4/6], Loss: 1.3445, Val Loss: 1.1970, Val Accuracy: 0.7364, 99% Accuracy: 0.1131
# Epoch [5/6], Loss: 1.8893, Val Loss: 0.8896, Val Accuracy: 0.8031, 99% Accuracy: 0.1334
# Epoch [6/6], Loss: 0.6509, Val Loss: 0.7050, Val Accuracy: 0.8535, 99% Accuracy: 0.2246
# Category: 3 | Best Loss: 0.7049565599723295
# Category: 3 | Best Hyperparameters: {'layer1': 1014, 'layer2': 208, 'dropout_rate': 0.30276111895219093, 'learning_rate': 0.00027292587500878367}
# Category: 3 | Number of learnable weights: 2818314
# Epoch [1/50], Loss: 4.0478, Val Loss: 3.5044, Val Accuracy: 0.3499, 99% Accuracy: 0.0024
# Epoch [2/50], Loss: 1.5884, Val Loss: 2.3603, Val Accuracy: 0.5411, 99% Accuracy: 0.0041
# Epoch [3/50], Loss: 3.6261, Val Loss: 1.6379, Val Accuracy: 0.6566, 99% Accuracy: 0.0350
# Epoch [4/50], Loss: 1.0694, Val Loss: 1.2276, Val Accuracy: 0.7396, 99% Accuracy: 0.0903
# Epoch [5/50], Loss: 1.7229, Val Loss: 0.9561, Val Accuracy: 0.7803, 99% Accuracy: 0.1758
# Epoch [6/50], Loss: 1.2086, Val Loss: 0.7502, Val Accuracy: 0.8210, 99% Accuracy: 0.2335
# Epoch [7/50], Loss: 0.9947, Val Loss: 0.6341, Val Accuracy: 0.8560, 99% Accuracy: 0.2718
# Epoch [8/50], Loss: 0.4081, Val Loss: 0.5135, Val Accuracy: 0.8885, 99% Accuracy: 0.3507
# Epoch [9/50], Loss: 0.5544, Val Loss: 0.4783, Val Accuracy: 0.8885, 99% Accuracy: 0.3897
# Epoch [10/50], Loss: 0.3181, Val Loss: 0.4144, Val Accuracy: 0.9129, 99% Accuracy: 0.4337
# Epoch [11/50], Loss: 0.6302, Val Loss: 0.3632, Val Accuracy: 0.9292, 99% Accuracy: 0.4776
# Epoch [12/50], Loss: 0.5028, Val Loss: 0.3552, Val Accuracy: 0.9308, 99% Accuracy: 0.5395
# Epoch [13/50], Loss: 0.2580, Val Loss: 0.3149, Val Accuracy: 0.9414, 99% Accuracy: 0.5736
# Epoch [14/50], Loss: 0.2493, Val Loss: 0.3336, Val Accuracy: 0.9455, 99% Accuracy: 0.6046
# Epoch [15/50], Loss: 0.1433, Val Loss: 0.2987, Val Accuracy: 0.9544, 99% Accuracy: 0.6184
# Epoch [16/50], Loss: 0.3879, Val Loss: 0.2874, Val Accuracy: 0.9487, 99% Accuracy: 0.6436
# Epoch [17/50], Loss: 0.1309, Val Loss: 0.2761, Val Accuracy: 0.9577, 99% Accuracy: 0.7006
# Epoch [18/50], Loss: 0.1760, Val Loss: 0.2681, Val Accuracy: 0.9544, 99% Accuracy: 0.6965
# Epoch [19/50], Loss: 0.6786, Val Loss: 0.3009, Val Accuracy: 0.9561, 99% Accuracy: 0.7299
# Epoch [20/50], Loss: 0.1561, Val Loss: 0.2655, Val Accuracy: 0.9601, 99% Accuracy: 0.7510
# Epoch [21/50], Loss: 0.0299, Val Loss: 0.2758, Val Accuracy: 0.9626, 99% Accuracy: 0.7925
# Epoch [22/50], Loss: 0.1356, Val Loss: 0.2565, Val Accuracy: 0.9634, 99% Accuracy: 0.7925
# Epoch [23/50], Loss: 0.0172, Val Loss: 0.3027, Val Accuracy: 0.9561, 99% Accuracy: 0.8039
# Epoch [24/50], Loss: 0.2921, Val Loss: 0.3026, Val Accuracy: 0.9569, 99% Accuracy: 0.7746
# Epoch [25/50], Loss: 0.0095, Val Loss: 0.2959, Val Accuracy: 0.9601, 99% Accuracy: 0.8218
# Epoch [26/50], Loss: 0.0523, Val Loss: 0.2940, Val Accuracy: 0.9642, 99% Accuracy: 0.8267
# Epoch [27/50], Loss: 0.0024, Val Loss: 0.2679, Val Accuracy: 0.9609, 99% Accuracy: 0.8381
# Epoch [28/50], Loss: 0.0686, Val Loss: 0.2784, Val Accuracy: 0.9618, 99% Accuracy: 0.8340
# Epoch [29/50], Loss: 0.6021, Val Loss: 0.2858, Val Accuracy: 0.9658, 99% Accuracy: 0.8690
# Epoch [30/50], Loss: 0.0250, Val Loss: 0.2878, Val Accuracy: 0.9618, 99% Accuracy: 0.8560
# Epoch [31/50], Loss: 0.0379, Val Loss: 0.2829, Val Accuracy: 0.9618, 99% Accuracy: 0.8552
# Epoch [32/50], Loss: 0.0258, Val Loss: 0.3250, Val Accuracy: 0.9601, 99% Accuracy: 0.8625
# Epoch [33/50], Loss: 0.1618, Val Loss: 0.2673, Val Accuracy: 0.9634, 99% Accuracy: 0.8771
# Epoch [34/50], Loss: 0.5553, Val Loss: 0.3012, Val Accuracy: 0.9618, 99% Accuracy: 0.8649
# Epoch [35/50], Loss: 0.3768, Val Loss: 0.3022, Val Accuracy: 0.9634, 99% Accuracy: 0.8763
# Epoch [36/50], Loss: 0.0144, Val Loss: 0.3256, Val Accuracy: 0.9609, 99% Accuracy: 0.8918
# Epoch [37/50], Loss: 0.0022, Val Loss: 0.3145, Val Accuracy: 0.9650, 99% Accuracy: 0.8885
# Epoch [38/50], Loss: 0.2093, Val Loss: 0.3092, Val Accuracy: 0.9618, 99% Accuracy: 0.8877
# Epoch [39/50], Loss: 0.0356, Val Loss: 0.3183, Val Accuracy: 0.9634, 99% Accuracy: 0.8706
# Epoch [40/50], Loss: 0.0176, Val Loss: 0.3172, Val Accuracy: 0.9618, 99% Accuracy: 0.8804
# Epoch [41/50], Loss: 0.0496, Val Loss: 0.3210, Val Accuracy: 0.9626, 99% Accuracy: 0.8950
# Epoch [42/50], Loss: 0.0358, Val Loss: 0.2910, Val Accuracy: 0.9683, 99% Accuracy: 0.9097
# Epoch [43/50], Loss: 0.0156, Val Loss: 0.3285, Val Accuracy: 0.9658, 99% Accuracy: 0.9081
# Epoch [44/50], Loss: 0.0159, Val Loss: 0.3052, Val Accuracy: 0.9683, 99% Accuracy: 0.9203
# Epoch [45/50], Loss: 0.0050, Val Loss: 0.3212, Val Accuracy: 0.9618, 99% Accuracy: 0.9138
# Epoch [46/50], Loss: 0.0442, Val Loss: 0.3182, Val Accuracy: 0.9650, 99% Accuracy: 0.9024
# Epoch [47/50], Loss: 0.0717, Val Loss: 0.3341, Val Accuracy: 0.9634, 99% Accuracy: 0.9227
# Epoch [48/50], Loss: 0.3915, Val Loss: 0.3311, Val Accuracy: 0.9683, 99% Accuracy: 0.9105
# Epoch [49/50], Loss: 0.0149, Val Loss: 0.3048, Val Accuracy: 0.9675, 99% Accuracy: 0.9235
# Epoch [50/50], Loss: 0.0074, Val Loss: 0.3393, Val Accuracy: 0.9666, 99% Accuracy: 0.9235
# c:\Users\Austin\anaconda3\envs\condaenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Austin\anaconda3\envs\condaenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics and definitions saved to BigBasket_Category_3_train_logs_2024-11-17_04-13_PM\BigBasket_Category_3_brand_metrics_output.xlsx
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\2680378259.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels, dtype=torch.float32)
# --- Params (iter 1) ---
# layer1: 654, layer2: 615, dropout: 0.3525835626998758, learning_rate: 0.005673275297006618
# Epoch [1/6], Loss: 5.7677, Val Loss: 5.2523, Val Accuracy: 0.0678, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 5.1249, Val Loss: 5.0825, Val Accuracy: 0.0636, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 5.1104, Val Loss: 5.0438, Val Accuracy: 0.0628, 99% Accuracy: 0.0005
# Epoch [4/6], Loss: 5.9589, Val Loss: 5.1061, Val Accuracy: 0.0586, 99% Accuracy: 0.0026
# Epoch [5/6], Loss: 5.9363, Val Loss: 5.0591, Val Accuracy: 0.0681, 99% Accuracy: 0.0076
# Epoch [6/6], Loss: 5.5520, Val Loss: 5.2300, Val Accuracy: 0.0534, 99% Accuracy: 0.0060
# --- Params (iter 2) ---
# layer1: 458, layer2: 463, dropout: 0.2426296094680923, learning_rate: 1.812954285966533e-06
# Epoch [1/6], Loss: 8.0766, Val Loss: 8.0105, Val Accuracy: 0.0408, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 7.1762, Val Loss: 7.2068, Val Accuracy: 0.0411, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 6.7594, Val Loss: 6.0771, Val Accuracy: 0.0542, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 6.0719, Val Loss: 5.6067, Val Accuracy: 0.0987, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 5.3919, Val Loss: 5.3561, Val Accuracy: 0.1154, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 5.3855, Val Loss: 5.1748, Val Accuracy: 0.1380, 99% Accuracy: 0.0000
# --- Params (iter 3) ---
# layer1: 761, layer2: 443, dropout: 0.3462992245732667, learning_rate: 3.8011677095141077e-06
# Epoch [1/6], Loss: 6.8298, Val Loss: 6.9401, Val Accuracy: 0.0921, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 5.5560, Val Loss: 5.3784, Val Accuracy: 0.1259, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 5.9260, Val Loss: 4.9934, Val Accuracy: 0.1497, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 4.7573, Val Loss: 4.7350, Val Accuracy: 0.1746, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 4.8013, Val Loss: 4.5376, Val Accuracy: 0.1929, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 3.3241, Val Loss: 4.3726, Val Accuracy: 0.2063, 99% Accuracy: 0.0000
# --- Params (iter 4) ---
# layer1: 345, layer2: 460, dropout: 0.27976702336233766, learning_rate: 7.720848426364456e-06
# Epoch [1/6], Loss: 5.5110, Val Loss: 5.5214, Val Accuracy: 0.0804, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 5.2032, Val Loss: 4.8790, Val Accuracy: 0.1458, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 4.6865, Val Loss: 4.5024, Val Accuracy: 0.1777, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 4.6661, Val Loss: 4.2237, Val Accuracy: 0.2212, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 4.8821, Val Loss: 4.0051, Val Accuracy: 0.2440, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 4.6842, Val Loss: 3.8206, Val Accuracy: 0.2662, 99% Accuracy: 0.0000
# --- Params (iter 5) ---
# layer1: 872, layer2: 393, dropout: 0.19844142550544658, learning_rate: 0.0003646848090633433
# Epoch [1/6], Loss: 3.6672, Val Loss: 2.6034, Val Accuracy: 0.4215, 99% Accuracy: 0.0259
# Epoch [2/6], Loss: 2.3330, Val Loss: 1.8247, Val Accuracy: 0.5644, 99% Accuracy: 0.0772
# Epoch [3/6], Loss: 1.2992, Val Loss: 1.4582, Val Accuracy: 0.6309, 99% Accuracy: 0.1207
# Epoch [4/6], Loss: 1.1072, Val Loss: 1.1748, Val Accuracy: 0.7107, 99% Accuracy: 0.1613
# Epoch [5/6], Loss: 0.9510, Val Loss: 1.0156, Val Accuracy: 0.7497, 99% Accuracy: 0.2228
# Epoch [6/6], Loss: 1.5272, Val Loss: 0.8776, Val Accuracy: 0.7827, 99% Accuracy: 0.2589
# --- Params (iter 6) ---
# layer1: 415, layer2: 574, dropout: 0.165927384016192, learning_rate: 0.00025730720902465915
# Epoch [1/6], Loss: 2.4906, Val Loss: 2.5563, Val Accuracy: 0.4424, 99% Accuracy: 0.0128
# Epoch [2/6], Loss: 1.3536, Val Loss: 1.7855, Val Accuracy: 0.5817, 99% Accuracy: 0.0626
# Epoch [3/6], Loss: 1.2310, Val Loss: 1.4038, Val Accuracy: 0.6484, 99% Accuracy: 0.0995
# Epoch [4/6], Loss: 1.1766, Val Loss: 1.1450, Val Accuracy: 0.7094, 99% Accuracy: 0.1254
# Epoch [5/6], Loss: 1.2497, Val Loss: 0.9627, Val Accuracy: 0.7453, 99% Accuracy: 0.1903
# Epoch [6/6], Loss: 1.3351, Val Loss: 0.8520, Val Accuracy: 0.7791, 99% Accuracy: 0.2277
# Category: 4 | Best Loss: 0.851968337738863
# Category: 4 | Best Hyperparameters: {'layer1': 415, 'layer2': 574, 'dropout_rate': 0.165927384016192, 'learning_rate': 0.00025730720902465915}
# Category: 4 | Number of learnable weights: 3210819
# Epoch [1/50], Loss: 4.4822, Val Loss: 2.5420, Val Accuracy: 0.4330, 99% Accuracy: 0.0257
# Epoch [2/50], Loss: 2.5099, Val Loss: 1.7864, Val Accuracy: 0.5623, 99% Accuracy: 0.0743
# Epoch [3/50], Loss: 2.8524, Val Loss: 1.3632, Val Accuracy: 0.6628, 99% Accuracy: 0.1065
# Epoch [4/50], Loss: 0.8836, Val Loss: 1.1777, Val Accuracy: 0.7060, 99% Accuracy: 0.1584
# Epoch [5/50], Loss: 0.9697, Val Loss: 1.0266, Val Accuracy: 0.7398, 99% Accuracy: 0.1937
# Epoch [6/50], Loss: 0.8962, Val Loss: 0.8635, Val Accuracy: 0.7835, 99% Accuracy: 0.2440
# Epoch [7/50], Loss: 1.4522, Val Loss: 0.7591, Val Accuracy: 0.8251, 99% Accuracy: 0.2859
# Epoch [8/50], Loss: 0.5870, Val Loss: 0.7032, Val Accuracy: 0.8490, 99% Accuracy: 0.3238
# Epoch [9/50], Loss: 0.2393, Val Loss: 0.6520, Val Accuracy: 0.8573, 99% Accuracy: 0.3822
# Epoch [10/50], Loss: 0.4535, Val Loss: 0.6182, Val Accuracy: 0.8767, 99% Accuracy: 0.4139
# Epoch [11/50], Loss: 0.2564, Val Loss: 0.6059, Val Accuracy: 0.8712, 99% Accuracy: 0.4610
# Epoch [12/50], Loss: 0.4629, Val Loss: 0.5887, Val Accuracy: 0.8893, 99% Accuracy: 0.5162
# Epoch [13/50], Loss: 0.2712, Val Loss: 0.5573, Val Accuracy: 0.9034, 99% Accuracy: 0.5455
# Epoch [14/50], Loss: 0.2003, Val Loss: 0.5590, Val Accuracy: 0.9005, 99% Accuracy: 0.5704
# Epoch [15/50], Loss: 0.3117, Val Loss: 0.5581, Val Accuracy: 0.9094, 99% Accuracy: 0.5877
# Epoch [16/50], Loss: 0.3075, Val Loss: 0.5524, Val Accuracy: 0.9139, 99% Accuracy: 0.6385
# Epoch [17/50], Loss: 0.5604, Val Loss: 0.5770, Val Accuracy: 0.9099, 99% Accuracy: 0.6291
# Epoch [18/50], Loss: 0.0007, Val Loss: 0.5408, Val Accuracy: 0.9207, 99% Accuracy: 0.6440
# Epoch [19/50], Loss: 0.0033, Val Loss: 0.5647, Val Accuracy: 0.9202, 99% Accuracy: 0.6804
# Epoch [20/50], Loss: 0.1229, Val Loss: 0.5563, Val Accuracy: 0.9262, 99% Accuracy: 0.6893
# Epoch [21/50], Loss: 0.3154, Val Loss: 0.5400, Val Accuracy: 0.9262, 99% Accuracy: 0.7178
# Epoch [22/50], Loss: 0.0162, Val Loss: 0.6360, Val Accuracy: 0.9202, 99% Accuracy: 0.7225
# Epoch [23/50], Loss: 0.0048, Val Loss: 0.6381, Val Accuracy: 0.9301, 99% Accuracy: 0.7377
# Epoch [24/50], Loss: 0.1065, Val Loss: 0.6153, Val Accuracy: 0.9283, 99% Accuracy: 0.7476
# Epoch [25/50], Loss: 0.1030, Val Loss: 0.5946, Val Accuracy: 0.9254, 99% Accuracy: 0.7380
# Epoch [26/50], Loss: 0.0006, Val Loss: 0.5798, Val Accuracy: 0.9359, 99% Accuracy: 0.7757
# Epoch [27/50], Loss: 0.1720, Val Loss: 0.6153, Val Accuracy: 0.9293, 99% Accuracy: 0.7647
# Epoch [28/50], Loss: 0.0965, Val Loss: 0.6049, Val Accuracy: 0.9338, 99% Accuracy: 0.7872
# Epoch [29/50], Loss: 0.0023, Val Loss: 0.6613, Val Accuracy: 0.9285, 99% Accuracy: 0.7720
# Epoch [30/50], Loss: 0.1924, Val Loss: 0.6457, Val Accuracy: 0.9325, 99% Accuracy: 0.7743
# Epoch [31/50], Loss: 0.0116, Val Loss: 0.6092, Val Accuracy: 0.9364, 99% Accuracy: 0.8207
# Epoch [32/50], Loss: 0.1290, Val Loss: 0.6520, Val Accuracy: 0.9403, 99% Accuracy: 0.8162
# Epoch [33/50], Loss: 0.0012, Val Loss: 0.6392, Val Accuracy: 0.9406, 99% Accuracy: 0.8223
# Epoch [34/50], Loss: 0.0011, Val Loss: 0.6462, Val Accuracy: 0.9395, 99% Accuracy: 0.8175
# Epoch [35/50], Loss: 0.0008, Val Loss: 0.6457, Val Accuracy: 0.9411, 99% Accuracy: 0.8277
# Epoch [36/50], Loss: 0.0004, Val Loss: 0.7173, Val Accuracy: 0.9340, 99% Accuracy: 0.8398
# Epoch [37/50], Loss: 0.3418, Val Loss: 0.7434, Val Accuracy: 0.9385, 99% Accuracy: 0.8380
# Epoch [38/50], Loss: 0.0561, Val Loss: 0.7152, Val Accuracy: 0.9325, 99% Accuracy: 0.8398
# Epoch [39/50], Loss: 0.0838, Val Loss: 0.7342, Val Accuracy: 0.9393, 99% Accuracy: 0.8482
# Epoch [40/50], Loss: 0.0006, Val Loss: 0.7249, Val Accuracy: 0.9351, 99% Accuracy: 0.8552
# Epoch [41/50], Loss: 0.0420, Val Loss: 0.7684, Val Accuracy: 0.9366, 99% Accuracy: 0.8461
# Epoch [42/50], Loss: 0.0017, Val Loss: 0.7076, Val Accuracy: 0.9390, 99% Accuracy: 0.8555
# Epoch [43/50], Loss: 0.0617, Val Loss: 0.7710, Val Accuracy: 0.9338, 99% Accuracy: 0.8505
# Epoch [44/50], Loss: 0.4280, Val Loss: 0.7703, Val Accuracy: 0.9372, 99% Accuracy: 0.8728
# Epoch [45/50], Loss: 0.0109, Val Loss: 0.7718, Val Accuracy: 0.9348, 99% Accuracy: 0.8484
# Epoch [46/50], Loss: 0.0113, Val Loss: 0.7695, Val Accuracy: 0.9369, 99% Accuracy: 0.8670
# Epoch [47/50], Loss: 0.0041, Val Loss: 0.8076, Val Accuracy: 0.9380, 99% Accuracy: 0.8639
# Epoch [48/50], Loss: 0.0009, Val Loss: 0.7756, Val Accuracy: 0.9382, 99% Accuracy: 0.8712
# Epoch [49/50], Loss: 0.0542, Val Loss: 0.8441, Val Accuracy: 0.9401, 99% Accuracy: 0.8775
# Epoch [50/50], Loss: 0.0367, Val Loss: 0.8199, Val Accuracy: 0.9393, 99% Accuracy: 0.8798
# c:\Users\Austin\anaconda3\envs\condaenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Austin\anaconda3\envs\condaenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics and definitions saved to BigBasket_Category_4_train_logs_2024-11-17_04-13_PM\BigBasket_Category_4_brand_metrics_output.xlsx
# --- Params (iter 1) ---
# layer1: 891, layer2: 1016, dropout: 0.23329885934628397, learning_rate: 0.0034692553985404364
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\2680378259.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels, dtype=torch.float32)
# Epoch [1/6], Loss: 1.1846, Val Loss: 0.9253, Val Accuracy: 0.6951, 99% Accuracy: 0.1829
# Epoch [2/6], Loss: 0.2018, Val Loss: 1.0564, Val Accuracy: 0.7561, 99% Accuracy: 0.3902
# Epoch [3/6], Loss: 0.0675, Val Loss: 0.2660, Val Accuracy: 0.9268, 99% Accuracy: 0.6585
# Epoch [4/6], Loss: 0.0298, Val Loss: 0.2477, Val Accuracy: 0.8902, 99% Accuracy: 0.6585
# Epoch [5/6], Loss: 0.2798, Val Loss: 0.2424, Val Accuracy: 0.9268, 99% Accuracy: 0.7439
# Epoch [6/6], Loss: 0.2987, Val Loss: 0.5129, Val Accuracy: 0.8537, 99% Accuracy: 0.7317
# --- Params (iter 2) ---
# ...
# Epoch [6/6], Loss: 7.8383, Val Loss: 8.0855, Val Accuracy: 0.1667, 99% Accuracy: 0.0000
# --- Params (iter 5) ---
# layer1: 480, layer2: 134, dropout: 0.16658944112016572, learning_rate: 1.1137997437850327e-05
# Epoch [1/6], Loss: 8.2117, Val Loss: 8.2550, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 8.3226, Val Loss: 8.2299, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 8.1011, Val Loss: 8.2046, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 8.1140, Val Loss: 8.1777, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 8.0587, Val Loss: 8.1508, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 7.9958, Val Loss: 8.1252, Val Accuracy: 0.0000, 99% Accuracy: 0.0000
# --- Params (iter 6) ---
# layer1: 446, layer2: 522, dropout: 0.3963957956976968, learning_rate: 0.0010791025241115623
# Epoch [1/6], Loss: 6.2325, Val Loss: 4.6847, Val Accuracy: 0.3333, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 7.3271, Val Loss: 3.3886, Val Accuracy: 0.5000, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 2.1554, Val Loss: 1.9657, Val Accuracy: 0.6667, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 1.2996, Val Loss: 1.3082, Val Accuracy: 0.8333, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 0.9457, Val Loss: 1.4805, Val Accuracy: 0.6667, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 0.8103, Val Loss: 0.8649, Val Accuracy: 0.5000, 99% Accuracy: 0.3333
# Category: 8 | Best Loss: 0.09231200069189072
# Category: 8 | Best Hyperparameters: {'layer1': 397, 'layer2': 771, 'dropout_rate': 0.1960500392527187, 'learning_rate': 0.005200128013493214}
# Category: 8 | Number of learnable weights: 4013775
# Epoch [1/50], Loss: 6.9364, Val Loss: 11.9512, Val Accuracy: 0.1667, 99% Accuracy: 0.0000
# Epoch [2/50], Loss: 3.6456, Val Loss: 3.6131, Val Accuracy: 0.1667, 99% Accuracy: 0.0000
# Epoch [3/50], Loss: 2.1875, Val Loss: 1.4885, Val Accuracy: 0.5000, 99% Accuracy: 0.0000
# Epoch [4/50], Loss: 0.3661, Val Loss: 0.4865, Val Accuracy: 0.8333, 99% Accuracy: 0.0000
# Epoch [5/50], Loss: 1.0451, Val Loss: 0.2151, Val Accuracy: 1.0000, 99% Accuracy: 0.0000
# Epoch [6/50], Loss: 0.0149, Val Loss: 0.6327, Val Accuracy: 0.8333, 99% Accuracy: 0.1667
# Epoch [7/50], Loss: 0.0165, Val Loss: 0.1014, Val Accuracy: 1.0000, 99% Accuracy: 0.3333
# Epoch [8/50], Loss: 0.2593, Val Loss: 0.0742, Val Accuracy: 1.0000, 99% Accuracy: 0.6667
# Epoch [9/50], Loss: 0.0000, Val Loss: 0.0227, Val Accuracy: 1.0000, 99% Accuracy: 0.6667
# Epoch [10/50], Loss: 0.0078, Val Loss: 0.0040, Val Accuracy: 1.0000, 99% Accuracy: 0.8333
# Epoch [11/50], Loss: 0.0271, Val Loss: 0.0043, Val Accuracy: 1.0000, 99% Accuracy: 0.8333
# Epoch [12/50], Loss: 0.0000, Val Loss: 0.0024, Val Accuracy: 1.0000, 99% Accuracy: 0.8333
# Epoch [13/50], Loss: 0.0004, Val Loss: 0.0109, Val Accuracy: 1.0000, 99% Accuracy: 0.6667
# Epoch [14/50], Loss: 0.0857, Val Loss: 0.0860, Val Accuracy: 1.0000, 99% Accuracy: 0.6667
# Epoch [15/50], Loss: 0.0000, Val Loss: 0.0086, Val Accuracy: 1.0000, 99% Accuracy: 0.8333
# Epoch [16/50], Loss: 0.0000, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [17/50], Loss: 0.0000, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [18/50], Loss: 0.0000, Val Loss: 0.0041, Val Accuracy: 1.0000, 99% Accuracy: 0.8333
# Epoch [19/50], Loss: 0.0000, Val Loss: 0.0016, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [20/50], Loss: 0.0000, Val Loss: 0.0004, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [21/50], Loss: 0.0005, Val Loss: 0.0002, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [22/50], Loss: 0.0005, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [23/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [24/50], Loss: 0.0032, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [25/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [26/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [27/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [28/50], Loss: 0.0061, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [29/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [30/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [31/50], Loss: 0.0000, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [32/50], Loss: 0.0003, Val Loss: 0.0517, Val Accuracy: 1.0000, 99% Accuracy: 0.8333
# Epoch [33/50], Loss: 0.0000, Val Loss: 0.7231, Val Accuracy: 0.8333, 99% Accuracy: 0.8333
# Epoch [34/50], Loss: 0.0000, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [35/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [36/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [37/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [38/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [39/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [40/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [41/50], Loss: 0.0000, Val Loss: 0.0634, Val Accuracy: 1.0000, 99% Accuracy: 0.8333
# Epoch [42/50], Loss: 0.0000, Val Loss: 0.0001, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [43/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [44/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [45/50], Loss: 0.0259, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [46/50], Loss: 0.0070, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [47/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [48/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [49/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Epoch [50/50], Loss: 0.0000, Val Loss: 0.0000, Val Accuracy: 1.0000, 99% Accuracy: 1.0000
# Metrics and definitions saved to BigBasket_Category_8_train_logs_2024-11-17_04-13_PM\BigBasket_Category_8_brand_metrics_output.xlsx
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\2680378259.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.labels = torch.tensor(labels, dtype=torch.float32)
# --- Params (iter 1) ---
# layer1: 858, layer2: 1022, dropout: 0.07661810378450411, learning_rate: 5.217677937738591e-06
# Epoch [1/6], Loss: 7.2149, Val Loss: 5.3925, Val Accuracy: 0.1421, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 4.8003, Val Loss: 4.3168, Val Accuracy: 0.2601, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 1.8524, Val Loss: 3.5641, Val Accuracy: 0.3875, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 4.9455, Val Loss: 3.0276, Val Accuracy: 0.4610, 99% Accuracy: 0.0003
# Epoch [5/6], Loss: 2.1352, Val Loss: 2.6314, Val Accuracy: 0.5234, 99% Accuracy: 0.0013
# Epoch [6/6], Loss: 2.0500, Val Loss: 2.3301, Val Accuracy: 0.5637, 99% Accuracy: 0.0038
# --- Params (iter 2) ---
# layer1: 923, layer2: 151, dropout: 0.2844269219611914, learning_rate: 1.5207937641454495e-06
# Epoch [1/6], Loss: 8.2997, Val Loss: 8.1634, Val Accuracy: 0.0028, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 7.7859, Val Loss: 7.9024, Val Accuracy: 0.0301, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 7.4601, Val Loss: 7.4604, Val Accuracy: 0.0399, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 6.8577, Val Loss: 7.0252, Val Accuracy: 0.0541, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 6.8125, Val Loss: 6.6949, Val Accuracy: 0.0621, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 5.5657, Val Loss: 6.4445, Val Accuracy: 0.0724, 99% Accuracy: 0.0000
# --- Params (iter 3) ---
# layer1: 702, layer2: 376, dropout: 0.1983020639453883, learning_rate: 1.5189791438873173e-05
# Epoch [1/6], Loss: 5.0545, Val Loss: 4.9063, Val Accuracy: 0.1982, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 3.6030, Val Loss: 3.8338, Val Accuracy: 0.3400, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 3.8700, Val Loss: 3.1038, Val Accuracy: 0.4590, 99% Accuracy: 0.0003
# Epoch [4/6], Loss: 4.2890, Val Loss: 2.6160, Val Accuracy: 0.5309, 99% Accuracy: 0.0045
# Epoch [5/6], Loss: 1.8523, Val Loss: 2.2626, Val Accuracy: 0.5789, 99% Accuracy: 0.0124
# Epoch [6/6], Loss: 0.5599, Val Loss: 1.9940, Val Accuracy: 0.6200, 99% Accuracy: 0.0212
# --- Params (iter 4) ---
# layer1: 499, layer2: 245, dropout: 0.27633453099191413, learning_rate: 0.00018788942161475724
# Epoch [1/6], Loss: 5.0148, Val Loss: 2.5813, Val Accuracy: 0.5259, 99% Accuracy: 0.0272
# Epoch [2/6], Loss: 2.9619, Val Loss: 1.6652, Val Accuracy: 0.6721, 99% Accuracy: 0.1373
# Epoch [3/6], Loss: 1.5933, Val Loss: 1.2189, Val Accuracy: 0.7447, 99% Accuracy: 0.2156
# Epoch [4/6], Loss: 0.0536, Val Loss: 0.9308, Val Accuracy: 0.7991, 99% Accuracy: 0.3159
# Epoch [5/6], Loss: 0.1899, Val Loss: 0.7443, Val Accuracy: 0.8374, 99% Accuracy: 0.3802
# Epoch [6/6], Loss: 0.1195, Val Loss: 0.6519, Val Accuracy: 0.8526, 99% Accuracy: 0.4151
# --- Params (iter 5) ---
# layer1: 1002, layer2: 587, dropout: 0.0648632786575346, learning_rate: 4.855649481872692e-06
# Epoch [1/6], Loss: 6.8048, Val Loss: 5.7071, Val Accuracy: 0.1205, 99% Accuracy: 0.0000
# Epoch [2/6], Loss: 5.8633, Val Loss: 4.7717, Val Accuracy: 0.2126, 99% Accuracy: 0.0000
# Epoch [3/6], Loss: 6.3318, Val Loss: 4.1199, Val Accuracy: 0.2979, 99% Accuracy: 0.0000
# Epoch [4/6], Loss: 4.0193, Val Loss: 3.6093, Val Accuracy: 0.3802, 99% Accuracy: 0.0000
# Epoch [5/6], Loss: 2.9728, Val Loss: 3.2074, Val Accuracy: 0.4372, 99% Accuracy: 0.0000
# Epoch [6/6], Loss: 2.1531, Val Loss: 2.8812, Val Accuracy: 0.4910, 99% Accuracy: 0.0003
# --- Params (iter 6) ---
# layer1: 982, layer2: 442, dropout: 0.0743218220232106, learning_rate: 0.0006843258569816859
# Epoch [1/6], Loss: 2.5948, Val Loss: 1.7800, Val Accuracy: 0.6342, 99% Accuracy: 0.2153
# Epoch [2/6], Loss: 1.0535, Val Loss: 1.0713, Val Accuracy: 0.7576, 99% Accuracy: 0.3665
# Epoch [3/6], Loss: 0.6470, Val Loss: 0.7818, Val Accuracy: 0.8240, 99% Accuracy: 0.4802
# Epoch [4/6], Loss: 0.0906, Val Loss: 0.7082, Val Accuracy: 0.8487, 99% Accuracy: 0.5496
# Epoch [5/6], Loss: 1.0053, Val Loss: 0.6259, Val Accuracy: 0.8758, 99% Accuracy: 0.6254
# Epoch [6/6], Loss: 0.3468, Val Loss: 0.6352, Val Accuracy: 0.8816, 99% Accuracy: 0.6632
# Category: 9 | Best Loss: 0.6352317576698846
# Category: 9 | Best Hyperparameters: {'layer1': 982, 'layer2': 442, 'dropout_rate': 0.0743218220232106, 'learning_rate': 0.0006843258569816859}
# Category: 9 | Number of learnable weights: 3895800
# Epoch [1/50], Loss: 2.7959, Val Loss: 1.6912, Val Accuracy: 0.6433, 99% Accuracy: 0.2072
# Epoch [2/50], Loss: 0.4037, Val Loss: 1.0223, Val Accuracy: 0.7645, 99% Accuracy: 0.3532
# Epoch [3/50], Loss: 0.1126, Val Loss: 0.7952, Val Accuracy: 0.8145, 99% Accuracy: 0.5017
# Epoch [4/50], Loss: 0.4710, Val Loss: 0.6611, Val Accuracy: 0.8526, 99% Accuracy: 0.5617
# Epoch [5/50], Loss: 0.0024, Val Loss: 0.6114, Val Accuracy: 0.8708, 99% Accuracy: 0.6456
# Epoch [6/50], Loss: 0.0515, Val Loss: 0.5675, Val Accuracy: 0.8871, 99% Accuracy: 0.6753
# Epoch [7/50], Loss: 0.5525, Val Loss: 0.5743, Val Accuracy: 0.8997, 99% Accuracy: 0.7120
# Epoch [8/50], Loss: 0.0211, Val Loss: 0.5972, Val Accuracy: 0.8955, 99% Accuracy: 0.7228
# Epoch [9/50], Loss: 0.2643, Val Loss: 0.5735, Val Accuracy: 0.9195, 99% Accuracy: 0.7771
# Epoch [10/50], Loss: 0.0050, Val Loss: 0.5783, Val Accuracy: 0.9199, 99% Accuracy: 0.7915
# Epoch [11/50], Loss: 0.2131, Val Loss: 0.6926, Val Accuracy: 0.9154, 99% Accuracy: 0.7998
# Epoch [12/50], Loss: 0.0000, Val Loss: 0.5789, Val Accuracy: 0.9331, 99% Accuracy: 0.8410
# Epoch [13/50], Loss: 0.0000, Val Loss: 0.6829, Val Accuracy: 0.9333, 99% Accuracy: 0.8523
# Epoch [14/50], Loss: 0.0001, Val Loss: 0.6870, Val Accuracy: 0.9313, 99% Accuracy: 0.8493
# Epoch [15/50], Loss: 2.0767, Val Loss: 0.6961, Val Accuracy: 0.9349, 99% Accuracy: 0.8578
# Epoch [16/50], Loss: 0.0000, Val Loss: 0.8415, Val Accuracy: 0.9248, 99% Accuracy: 0.8614
# Epoch [17/50], Loss: 0.0001, Val Loss: 0.7952, Val Accuracy: 0.9379, 99% Accuracy: 0.8838
# Epoch [18/50], Loss: 0.0006, Val Loss: 0.8289, Val Accuracy: 0.9427, 99% Accuracy: 0.8937
# Epoch [19/50], Loss: 0.5845, Val Loss: 0.8231, Val Accuracy: 0.9455, 99% Accuracy: 0.8952
# Epoch [20/50], Loss: 1.1299, Val Loss: 0.8322, Val Accuracy: 0.9442, 99% Accuracy: 0.9066
# Epoch [21/50], Loss: 0.0000, Val Loss: 0.9259, Val Accuracy: 0.9478, 99% Accuracy: 0.9096
# Epoch [22/50], Loss: 0.0000, Val Loss: 1.0509, Val Accuracy: 0.9381, 99% Accuracy: 0.8993
# Epoch [23/50], Loss: 1.0744, Val Loss: 1.0454, Val Accuracy: 0.9439, 99% Accuracy: 0.9089
# Epoch [24/50], Loss: 0.0006, Val Loss: 1.1680, Val Accuracy: 0.9410, 99% Accuracy: 0.9121
# Epoch [25/50], Loss: 0.0000, Val Loss: 0.9817, Val Accuracy: 0.9502, 99% Accuracy: 0.9222
# Epoch [26/50], Loss: 0.0001, Val Loss: 1.1685, Val Accuracy: 0.9463, 99% Accuracy: 0.9215
# Epoch [27/50], Loss: 0.0001, Val Loss: 1.1548, Val Accuracy: 0.9454, 99% Accuracy: 0.9199
# Epoch [28/50], Loss: 0.0000, Val Loss: 1.1047, Val Accuracy: 0.9459, 99% Accuracy: 0.9210
# Epoch [29/50], Loss: 0.0002, Val Loss: 1.1112, Val Accuracy: 0.9487, 99% Accuracy: 0.9288
# Epoch [30/50], Loss: 0.0081, Val Loss: 1.2342, Val Accuracy: 0.9510, 99% Accuracy: 0.9296
# Epoch [31/50], Loss: 0.0370, Val Loss: 1.2976, Val Accuracy: 0.9495, 99% Accuracy: 0.9311
# Epoch [32/50], Loss: 0.0000, Val Loss: 1.2541, Val Accuracy: 0.9450, 99% Accuracy: 0.9256
# Epoch [33/50], Loss: 0.0000, Val Loss: 1.4114, Val Accuracy: 0.9510, 99% Accuracy: 0.9366
# Epoch [34/50], Loss: 0.0000, Val Loss: 1.4580, Val Accuracy: 0.9518, 99% Accuracy: 0.9338
# Epoch [35/50], Loss: 0.0000, Val Loss: 1.4581, Val Accuracy: 0.9512, 99% Accuracy: 0.9369
# Epoch [36/50], Loss: 0.0000, Val Loss: 1.5808, Val Accuracy: 0.9535, 99% Accuracy: 0.9397
# Epoch [37/50], Loss: 0.0000, Val Loss: 1.5931, Val Accuracy: 0.9538, 99% Accuracy: 0.9417
# Epoch [38/50], Loss: 0.0006, Val Loss: 1.4780, Val Accuracy: 0.9561, 99% Accuracy: 0.9460
# Epoch [39/50], Loss: 0.0000, Val Loss: 1.6524, Val Accuracy: 0.9535, 99% Accuracy: 0.9455
# Epoch [40/50], Loss: 0.0000, Val Loss: 1.5719, Val Accuracy: 0.9581, 99% Accuracy: 0.9472
# Epoch [41/50], Loss: 0.0000, Val Loss: 1.6660, Val Accuracy: 0.9546, 99% Accuracy: 0.9439
# Epoch [42/50], Loss: 0.0000, Val Loss: 1.6948, Val Accuracy: 0.9569, 99% Accuracy: 0.9463
# Epoch [43/50], Loss: 0.5583, Val Loss: 1.8373, Val Accuracy: 0.9566, 99% Accuracy: 0.9492
# Epoch [44/50], Loss: 0.0000, Val Loss: 1.9300, Val Accuracy: 0.9558, 99% Accuracy: 0.9454
# Epoch [45/50], Loss: 0.0000, Val Loss: 1.8699, Val Accuracy: 0.9583, 99% Accuracy: 0.9483
# Epoch [46/50], Loss: 0.0000, Val Loss: 2.0285, Val Accuracy: 0.9515, 99% Accuracy: 0.9434
# Epoch [47/50], Loss: 0.0000, Val Loss: 2.0462, Val Accuracy: 0.9584, 99% Accuracy: 0.9500
# Epoch [48/50], Loss: 0.0000, Val Loss: 2.0539, Val Accuracy: 0.9535, 99% Accuracy: 0.9480
# Epoch [49/50], Loss: 0.0000, Val Loss: 2.0201, Val Accuracy: 0.9598, 99% Accuracy: 0.9541
# Epoch [50/50], Loss: 0.0000, Val Loss: 2.1578, Val Accuracy: 0.9573, 99% Accuracy: 0.9520
# c:\Users\Austin\anaconda3\envs\condaenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Austin\anaconda3\envs\condaenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics and definitions saved to BigBasket_Category_9_train_logs_2024-11-17_04-13_PM\BigBasket_Category_9_brand_metrics_output.xlsx

# %%
models = [torch.load(model_path).eval() for model_path in model_paths]  # Load each model and set to eval mode

all_logits = []

# Evaluate each batch in the test dataloader
with torch.no_grad():  # Disable gradient calculation for evaluation
    for i in range(0, len(test_data)):
        
        # Predict the category first (using the category model, assumed to be the first model in list)
        emb = torch.tensor(test_data[i]).to(device)
        category_logits = models[0](emb)
        predicted_category = torch.argmax(category_logits)

        # Forward pass only through the specialized model for the predicted category
        logit = models[predicted_category+1](emb)
        all_logits.append(logit.cpu().numpy())

all_logits = np.array(all_logits)

save_directory = f"{dataset_title}final_eval_{current_time}"
file_name = f"{dataset_title}3_tier_prediction"
file_path = f'{save_directory}\\{file_name}_metrics_output.xlsx'

if not os.path.exists(save_directory):
    os.makedirs(save_directory)

evaluate_and_save_model_stats(all_logits, test_y_brand, metrics_title=file_name, file_path=file_path, print_metrics=True)
# Out:
# C:\Users\Austin\AppData\Local\Temp\ipykernel_4740\4112145743.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   models = [torch.load(model_path).eval() for model_path in model_paths]  # Load each model and set to eval mode
# c:\Users\Austin\anaconda3\envs\condaenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Austin\anaconda3\envs\condaenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# --- BigBasket_3_tier_prediction Default Metrics ---
# Accuracy: 0.947
# Precision: 0.954
# Recall: 0.958
# F1 Score: 0.956
# Adjusted Accuracy: 0.947
# Image Coverage: 1.0
# Brand Coverage: 0.989
#
# --- BigBasket_3_tier_prediction 95% Metrics ---
# Accuracy: 0.915
# Precision: 0.968
# Recall: 0.942
# F1 Score: 0.955
# Adjusted Accuracy: 0.975
# Image Coverage: 0.939
# Brand Coverage: 0.984
#
# --- BigBasket_3_tier_prediction 96% Metrics ---
# Accuracy: 0.913
# Precision: 0.968
# Recall: 0.94
# F1 Score: 0.954
# Adjusted Accuracy: 0.976
# Image Coverage: 0.935
# Brand Coverage: 0.984
#
# --- BigBasket_3_tier_prediction 97% Metrics ---
# Accuracy: 0.908
# Precision: 0.968
# Recall: 0.937
# F1 Score: 0.953
# Adjusted Accuracy: 0.977
# Image Coverage: 0.93
# Brand Coverage: 0.983
#
# --- BigBasket_3_tier_prediction 98% Metrics ---
# Accuracy: 0.903
# Precision: 0.968
# Recall: 0.934
# F1 Score: 0.951
# Adjusted Accuracy: 0.978
# Image Coverage: 0.922
# Brand Coverage: 0.982
#
# --- BigBasket_3_tier_prediction 99% Metrics ---
# Accuracy: 0.893
# Precision: 0.969
# Recall: 0.928
# F1 Score: 0.948
# Adjusted Accuracy: 0.981
# Image Coverage: 0.91
# Brand Coverage: 0.982
# Metrics and definitions saved to BigBasket_final_eval_2024-11-17_04-13_PM\BigBasket_3_tier_prediction_metrics_output.xlsx
